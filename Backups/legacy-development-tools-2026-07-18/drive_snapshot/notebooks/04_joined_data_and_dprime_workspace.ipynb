# %%
#@title Connect to the release { display-mode: "form" }
import importlib
import sys
import types
from pathlib import Path

from google.colab import drive as google_drive

google_drive.mount("/content/drive", force_remount=False)
WORKSPACE = Path(
    "/content/drive/MyDrive/Zhong et al. 2025 - Neuromatch Team Workspace"
)
required = (
    WORKSPACE / "drive.py",
    WORKSPACE / "graph.py",
    WORKSPACE / "zhong2025/atlas.py",
    WORKSPACE / "zhong2025/data.py",
    WORKSPACE / "zhong2025/assets/figshare-v2-inventory.json",
    WORKSPACE / "zhong2025/assets/imaging-experiment-index.json",
)
missing = [str(path) for path in required if not path.is_file()]
assert not missing, "Missing required workspace files:\n" + "\n".join(missing)

if str(WORKSPACE) not in sys.path:
    sys.path.insert(0, str(WORKSPACE))

# The shared Drive copy contains the data-access modules but not optional
# zhong2025 launcher/cache modules. Register the available package directory
# and expose only the helpers required by drive.py.
for module_name in list(sys.modules):
    if module_name in {"drive", "graph", "zhong2025"} or module_name.startswith("zhong2025."):
        sys.modules.pop(module_name, None)

zhong2025 = types.ModuleType("zhong2025")
zhong2025.__path__ = [str(WORKSPACE / "zhong2025")]
zhong2025.__package__ = "zhong2025"
sys.modules["zhong2025"] = zhong2025

atlas = importlib.import_module("zhong2025.atlas")
data_module = importlib.import_module("zhong2025.data")
for helper_name in (
    "experiment_rows",
    "format_bytes",
    "load_experiment_index",
    "load_file_inventory",
    "recording_bundle",
):
    setattr(zhong2025, helper_name, getattr(atlas, helper_name))
zhong2025.fetch_figshare_article = data_module.fetch_figshare_article

drive = importlib.import_module("drive")
graph = importlib.import_module("graph")
assert Path(drive.__file__).resolve() == (WORKSPACE / "drive.py").resolve()
assert Path(graph.__file__).resolve() == (WORKSPACE / "graph.py").resolve()

data = drive.setup(mount=False, report=False)
assert data.release["article_id"] == 28811129
assert data.release["version"] == 2
assert len(data.files) == 297
assert sum(item.size_bytes for item in data.files) == 452_233_500_962
data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset({'connected': True,
#  'availability': 'mounted',
#  'root': '/content/drive/MyDrive/Zhong et al. 2025 - Neuromatch Team Workspace/Janelia dataset - '
#          'Zhong et al. 2025 (Figshare v2)',
#  'cache': '/content/janelia_cache',
#  'release': {'article_id': 28811129,
#              'doi': '10.25378/janelia.28811129.v2',
#              'file_count': 297,
#              'inventory_sha256': '4f498b97501d038a83ab6ba52bfec109e3b540019bbd37602e9382eb600c3d14',
#              'license': 'CC BY 4.0',
#              'schema_version': 1,
#              'total_bytes': 452233500962,
#              'version': 2},
#  'published_file_count': 297,
#  'published_bytes': 452233500962,
#  'published_size': '421.2 GiB',
#  'experiment_count': 23,
#  'experiments': ('naive_test1',
#                  'naive_test2',
#                  'naive_test3',
#                  'sup_test1',
#                  'sup_test2',
#                  'sup_test3',
#                  'sup_train1_after_learning',
#                  'sup_train1_before_learning',
#                  'sup_train2_after_learning',
#                  'sup_train2_before_learning',
#                  'test1_after_grating',
#                  'test1_before_grating',
#                  'test2_after_grating',
#                  'test2_before_grating',
#                  'train1_after_grating',
#                  'train1_before_grating',
#                  'unsup_test1',
#                  'unsup_test2',
#                  'unsup_test3',
#                  'unsup_train1_after_learning',
#                  'unsup_train1_before_learning',
#                  'unsup_train2_after_learning',
#                  'unsup_train2_before_learning'),
#  'folders': ('_transfer_staging', 'data', 'metadata', 'team_tools'),
#  'public_attributes': {'data.connected': {'value': 'True',
#                                           'description': 'whether release files are mounted'},
#                        'data.root': {'value': '/content/drive/MyDrive/Zhong et al. 2025 - '
#                                               'Neuromatch Team Workspace/Janelia dataset - Zhong '
#                                               'et al. 2025 (Figshare v2)',
#                                      'description': 'mounted read-only dataset root'},
#                        'data.cache': {'value': '/content/janelia_cache',
#                                       'description': 'verified local file cache'},
#                        'data.release': {'value': 'dict (8 fields)',
#                                         'description': 'pinned release metadata'},
#                        'data.files': {'value': 'tuple[DataFile] (297 rows)',
#                                       'description': 'complete file catalog'},
#                        'data.experiments': {'value': 'tuple[str] (23 labels)',
#                                             'description': 'published analysis labels'},
#                        'data.folders': {'value': '_transfer_staging, data, metadata, team_tools',
#                                         'description': 'top-level mounted folders'}},
#  'api': {'data.fetch(selected, *, max_gib=10.0)': 'Copy and verify one selected Drive file into '
#                                                   'the local cache.',
#          'data.figshare(*, live=True)': 'Return the public Figshare API dictionary or the pinned '
#                                         'summary.',
#          'data.file(name)': 'Resolve one exact published filename.',
#          "data.find(*, category=None, contains='', experiment=None, recording_id=None, retinotopy_id=None)": 'Filter '
#                                                                                                              'the '
#                                                                                                              'catalog '
#                                                                                                              'without '
#                                                                                                              'scanning '
#                                                                                                              'or '
#                                                                                                              'opening '
#                                                                                                              'release '
#                                                                                                              'files.',
#          'data.load(selected=None, *, filename=None, recording=None, layer=None, experiment=None, max_gib=10.0)': 'Fetch, '
#                                                                                                                   'verify, '
#                                                                                                                   'and '
#                                                                                                                   'load '
#                                                                                                                   'one '
#                                                                                                                   'selected '
#                                                                                                                   'file '
#                                                                                                                   'or '
#                                                                                                                   'recording '
#                                                                                                                   'layer.',
#          'data.picker()': 'Return a compact notebook UI for selecting and loading Janelia data.',
#          'data.recording(recording_id)': 'Return one recording with its behavior, neural, and '
#                                          'cortical files.',
#          "data.recordings(*, experiment=None, mouse=None, contains='')": 'Find imaging recordings '
#                                                                          'by scientific identity, '
#                                                                          'not Drive paths.',
#          'data.to_dict()': 'Return a compact, copyable description of the dataset API.'},
#  'examples': {'choose': 'picker = data.picker()',
#               'find_recordings': 'sessions = data.recordings(mouse="TX119")',
#               'select_recording': 'session = data.recording("TX119_2023_12_24_1")',
#               'load_layer': 'sample = session.load("reduced_neural")'}})

# %%
info = data.load("Imaging_Exp_info.npy")
info.keys()
# Out:
# dict_keys(['unsup_train1_before_learning', 'unsup_train1_after_learning', 'sup_train1_before_learning', 'sup_train1_after_learning', 'unsup_test1', 'sup_test1', 'naive_test1', 'unsup_test2', 'sup_test2', 'naive_test2', 'unsup_test3', 'sup_test3', 'naive_test3', 'unsup_train2_before_learning', 'sup_train2_before_learning', 'unsup_train2_after_learning', 'sup_train2_after_learning', 'train1_before_grating', 'train1_after_grating', 'test1_before_grating', 'test1_after_grating', 'test2_before_grating', 'test2_after_grating'])

# %%
info['naive_test1']
# Out:
# array([{'sess#': 1, 'mname': 'TX108', 'datexp': '2023_01_05', 'blk': '2', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [250, 210], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,leaf0,leaf1', 'stim_id': array([0, 1, 2, 3]), 'Gender': 'Male'},
#        {'sess#': 1, 'mname': 'TX109', 'datexp': '2023_03_16', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [250, 210], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,leaf0,leaf1', 'stim_id': array([2, 3, 0, 1]), 'Gender': 'Male'},
#        {'sess#': 1, 'mname': 'TX119', 'datexp': '2023_12_12', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'rock0,rock1,brick0,brick1,brick5', 'stim_id': array([ 0.,  1.,  2.,  3., nan]), 'Gender': 'Male'},
#        {'sess#': 1, 'mname': 'TX123', 'datexp': '2023_12_18', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,circle2,leaf0,leaf0_swap1,leaf0_swap2,leaf1,leaf2', 'stim_id': array([ 0.,  1., nan,  2., nan, nan,  3., nan]), 'Gender': 'Male'},
#        {'sess#': 1, 'mname': 'TX124', 'datexp': '2023_12_23', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,circle2,leaf0,leaf1,leaf2', 'stim_id': array([ 0.,  1., nan,  2.,  3., nan]), 'Gender': 'Male'},
#        {'sess#': 1, 'mname': 'LZ13', 'datexp': '2024_05_15', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,leaf0,leaf1,leaf2', 'stim_id': array([ 0.,  1.,  2.,  3., nan]), 'Gender': 'Female'},
#        {'sess#': 2, 'mname': 'LZ13', 'datexp': '2024_05_16', 'blk': '2', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'rock0,rock1,brick0,brick1,brick5', 'stim_id': array([ 0.,  1.,  2.,  3., nan]), 'Gender': 'Female'},
#        {'sess#': 1, 'mname': 'LZ16', 'datexp': '2024_05_18', 'blk': '2', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,circle2,leaf0,leaf1,leaf2', 'stim_id': array([ 0.,  1., nan,  2.,  3., nan]), 'Gender': 'Female'},
#        {'sess#': 2, 'mname': 'LZ16', 'datexp': '2024_05_19', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'rock0,rock1,brick0,brick1,brick5', 'stim_id': array([ 0.,  1.,  2.,  3., nan]), 'Gender': 'Female'},
#        {'sess#': 1, 'mname': 'TX139', 'datexp': '2024_05_18', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,leaf0,leaf1,leaf2', 'stim_id': array([ 0.,  1.,  2.,  3., nan]), 'Gender': 'Male'},
#        {'sess#': 1, 'mname': 'TX140', 'datexp': '2024_05_31', 'blk': '1', 'is2p': 1, 'ROIdir': [], 'rewType': 'None', 'depth': [240, 200], 'Note': 'VR move when run', 'stim': 'cirlce0,circle1,leaf0,leaf1,leaf2', 'stim_id': array([ 0.,  1.,  2.,  3., nan]), 'Gender': 'Female'}],
#       dtype=object)

# %%
# we have neural data for these experiments
experiments = {
    "supervised": (
        "sup_train1_before_learning",
        "sup_train1_after_learning",
        "sup_test1",
        "sup_train2_before_learning",
        "sup_train2_after_learning",
        "sup_test2",
        "sup_test3",
    ),
    "unsupervised": (
        "unsup_train1_before_learning",
        "unsup_train1_after_learning",
        "unsup_test1",
        "unsup_train2_before_learning",
        "unsup_train2_after_learning",
        "unsup_test2",
        "unsup_test3",
    ),
    "grating": (
        "train1_before_grating",
        "train1_after_grating",
        "test1_before_grating",
        "test1_after_grating",
        "test2_before_grating",
        "test2_after_grating",
    ),
    "naive": (
        "naive_test1",
        "naive_test2",
        "naive_test3",
    ),
}

experiments
# Out:
# {'supervised': ('sup_train1_before_learning',
#   'sup_train1_after_learning',
#   'sup_test1',
#   'sup_train2_before_learning',
#   'sup_train2_after_learning',
#   'sup_test2',
#   'sup_test3'),
#  'unsupervised': ('unsup_train1_before_learning',
#   'unsup_train1_after_learning',
#   'unsup_test1',
#   'unsup_train2_before_learning',
#   'unsup_train2_after_learning',
#   'unsup_test2',
#   'unsup_test3'),
#  'grating': ('train1_before_grating',
#   'train1_after_grating',
#   'test1_before_grating',
#   'test1_after_grating',
#   'test2_before_grating',
#   'test2_after_grating'),
#  'naive': ('naive_test1', 'naive_test2', 'naive_test3')}

# %%
# we have neural data for these mice
mice = {
    "supervised": ['TX108', 'TX109', 'TX60', 'TX61', 'VR2'],
    "unsupervised": ['DR10', 'DR15', 'TX104', 'TX105', 'TX119', 'TX123', 'TX83', 'TX85', 'TX88'],
    "grating": ['LZ13', 'LZ16', 'TX139'],
    "naive": ['TX124', 'TX140'],
}

# %%
data.recordings(mouse = 'TX108')
# Out:
# [Recording({'recording_id': 'TX108_2023_01_05_2',
#   'mouse': 'TX108',
#   'date': '2023-01-05',
#   'block': '2',
#   'retinotopy_id': 'TX108_2023_01_05',
#   'experiments': ('naive_test1',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 6941629391,
#   'published_size': '6.5 GiB',
#   'files': [{'name': 'Beh_naive_test1.npy',
#              'figshare_file_id': 54183923,
#              'category': 'imaging_behavior',
#              'size_bytes': 432561586,
#              'size': '412.5 MiB',
#              'size_mib': 412.5228748321533,
#              'size_gib': 0.4028543699532747,
#              'md5': 'c582b1937ee1917dce1512036b346ba3',
#              'relative_path': 'data/beh/Beh_naive_test1.npy',
#              'experiment': 'naive_test1',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_naive_test1.npy · 412.5 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_naive_test1.npy")'},
#             {'name': 'TX108_2023_01_05_2_neural_data.npy',
#              'figshare_file_id': 54184736,
#              'category': 'full_neural',
#              'size_bytes': 6359799389,
#              'size': '5.9 GiB',
#              'size_mib': 6065.177334785461,
#              'size_gib': 5.923024741001427,
#              'md5': '189783922d03e65f0f60683a742f6b92',
#              'relative_path': 'data/spk/TX108_2023_01_05_2_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_01_05_2',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_01_05_2_neural_data.npy · 5.9 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_01_05_2_neural_data.npy")'},
#             {'name': 'TX108_2023_01_05_2_SVD_dec.npy',
#              'figshare_file_id': 54866267,
#              'category': 'reduced_neural',
#              'size_bytes': 146799266,
#              'size': '140.0 MiB',
#              'size_mib': 139.99868965148926,
#              'size_gib': 0.13671747036278248,
#              'md5': '4c50ab3ca0984ee6024c9d06736351d6',
#              'relative_path': 'data/SVD_dec/TX108_2023_01_05_2_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_01_05_2',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_01_05_2_SVD_dec.npy · 140.0 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_01_05_2_SVD_dec.npy")'},
#             {'name': 'TX108_2023_01_05_trans.npz',
#              'figshare_file_id': 54184043,
#              'category': 'retinotopy',
#              'size_bytes': 2469150,
#              'size': '2.4 MiB',
#              'size_mib': 2.354764938354492,
#              'size_gib': 0.0022995751351118088,
#              'md5': '475df8c485a8a3dc63fcffbfb583d922',
#              'relative_path': 'data/retinotopy/TX108_2023_01_05_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_01_05',
#              'label': 'TX108_2023_01_05_trans.npz · 2.4 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_01_05_trans.npz")'}],
#   'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_03_13_1',
#   'mouse': 'TX108',
#   'date': '2023-03-13',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_03_13',
#   'experiments': ('sup_train1_before_learning',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 8162717957,
#   'published_size': '7.6 GiB',
#   'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#              'figshare_file_id': 54183863,
#              'category': 'imaging_behavior',
#              'size_bytes': 124559852,
#              'size': '118.8 MiB',
#              'size_mib': 118.78953170776367,
#              'size_gib': 0.11600540205836296,
#              'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#              'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#              'experiment': 'sup_train1_before_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#             {'name': 'TX108_2023_03_13_1_neural_data.npy',
#              'figshare_file_id': 54184787,
#              'category': 'full_neural',
#              'size_bytes': 7861517081,
#              'size': '7.3 GiB',
#              'size_mib': 7497.326928138733,
#              'size_gib': 7.321608328260481,
#              'md5': '7198e6b915ab46c6d3e3ffd69603853a',
#              'relative_path': 'data/spk/TX108_2023_03_13_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_13_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_13_1_neural_data.npy · 7.3 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_13_1_neural_data.npy")'},
#             {'name': 'TX108_2023_03_13_1_SVD_dec.npy',
#              'figshare_file_id': 54866285,
#              'category': 'reduced_neural',
#              'size_bytes': 173562466,
#              'size': '165.5 MiB',
#              'size_mib': 165.522066116333,
#              'size_gib': 0.16164264269173145,
#              'md5': '66e74de2fa04b44473cb022fc218f369',
#              'relative_path': 'data/SVD_dec/TX108_2023_03_13_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_13_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_13_1_SVD_dec.npy · 165.5 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_13_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_03_13_trans.npz',
#              'figshare_file_id': 54184049,
#              'category': 'retinotopy',
#              'size_bytes': 3078558,
#              'size': '2.9 MiB',
#              'size_mib': 2.935941696166992,
#              'size_gib': 0.0028671305626630783,
#              'md5': 'ad11366cca099003be409687efb6a74c',
#              'relative_path': 'data/retinotopy/TX108_2023_03_13_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_03_13',
#              'label': 'TX108_2023_03_13_trans.npz · 2.9 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_03_13_trans.npz")'}],
#   'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                   'experiment="sup_train1_before_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_03_22_1',
#   'mouse': 'TX108',
#   'date': '2023-03-22',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_03_22',
#   'experiments': ('sup_train1_after_learning',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 6175517868,
#   'published_size': '5.8 GiB',
#   'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#              'figshare_file_id': 54183860,
#              'category': 'imaging_behavior',
#              'size_bytes': 113352887,
#              'size': '108.1 MiB',
#              'size_mib': 108.1017370223999,
#              'size_gib': 0.1055681025609374,
#              'md5': '08c7066c45c4edfb871ff29b314ba64a',
#              'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#              'experiment': 'sup_train1_after_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#             {'name': 'TX108_2023_03_22_1_neural_data.npy',
#              'figshare_file_id': 54184700,
#              'category': 'full_neural',
#              'size_bytes': 5907367193,
#              'size': '5.5 GiB',
#              'size_mib': 5633.704369544983,
#              'size_gib': 5.501664423383772,
#              'md5': '4cde6c5d3f33c3a1f5c65150c722a242',
#              'relative_path': 'data/spk/TX108_2023_03_22_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_22_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_22_1_neural_data.npy · 5.5 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_22_1_neural_data.npy")'},
#             {'name': 'TX108_2023_03_22_1_SVD_dec.npy',
#              'figshare_file_id': 54866273,
#              'category': 'reduced_neural',
#              'size_bytes': 152079266,
#              'size': '145.0 MiB',
#              'size_mib': 145.03409004211426,
#              'size_gib': 0.1416348535567522,
#              'md5': '0a933f53cbe7702b89467c66ebc07b34',
#              'relative_path': 'data/SVD_dec/TX108_2023_03_22_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_22_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_22_1_SVD_dec.npy · 145.0 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_22_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_03_22_trans.npz',
#              'figshare_file_id': 54184052,
#              'category': 'retinotopy',
#              'size_bytes': 2718522,
#              'size': '2.6 MiB',
#              'size_mib': 2.5925846099853516,
#              'size_gib': 0.00253182090818882,
#              'md5': '5083ea99f53082ef53df7fb0a1334a50',
#              'relative_path': 'data/retinotopy/TX108_2023_03_22_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_03_22',
#              'label': 'TX108_2023_03_22_trans.npz · 2.6 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_03_22_trans.npz")'}],
#   'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                  'experiment="sup_train1_after_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_03_25_1',
#   'mouse': 'TX108',
#   'date': '2023-03-25',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_03_25',
#   'experiments': ('sup_test1', 'sup_train2_before_learning'),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 5,
#   'published_bytes': 8983795993,
#   'published_size': '8.4 GiB',
#   'files': [{'name': 'Beh_sup_test1.npy',
#              'figshare_file_id': 54183875,
#              'category': 'imaging_behavior',
#              'size_bytes': 180666800,
#              'size': '172.3 MiB',
#              'size_mib': 172.2972869873047,
#              'size_gib': 0.16825906932353973,
#              'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#              'relative_path': 'data/beh/Beh_sup_test1.npy',
#              'experiment': 'sup_test1',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_test1.npy · 172.3 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_test1.npy")'},
#             {'name': 'Beh_sup_train2_before_learning.npy',
#              'figshare_file_id': 54183881,
#              'category': 'imaging_behavior',
#              'size_bytes': 180666800,
#              'size': '172.3 MiB',
#              'size_mib': 172.2972869873047,
#              'size_gib': 0.16825906932353973,
#              'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#              'relative_path': 'data/beh/Beh_sup_train2_before_learning.npy',
#              'experiment': 'sup_train2_before_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train2_before_learning.npy · 172.3 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train2_before_learning.npy")'},
#             {'name': 'TX108_2023_03_25_1_neural_data.npy',
#              'figshare_file_id': 54184793,
#              'category': 'full_neural',
#              'size_bytes': 8449969273,
#              'size': '7.9 GiB',
#              'size_mib': 8058.518670082092,
#              'size_gib': 7.869647138752043,
#              'md5': '3e87d3fcc74b2f841e4645cc78d0eac1',
#              'relative_path': 'data/spk/TX108_2023_03_25_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_25_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_25_1_neural_data.npy · 7.9 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_25_1_neural_data.npy")'},
#             {'name': 'TX108_2023_03_25_1_SVD_dec.npy',
#              'figshare_file_id': 54866288,
#              'category': 'reduced_neural',
#              'size_bytes': 169632866,
#              'size': '161.8 MiB',
#              'size_mib': 161.774507522583,
#              'size_gib': 0.15798291750252247,
#              'md5': '29900e2e23ffada97c2c5d8fecfe8858',
#              'relative_path': 'data/SVD_dec/TX108_2023_03_25_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_25_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_25_1_SVD_dec.npy · 161.8 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_25_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_03_25_trans.npz',
#              'figshare_file_id': 54184061,
#              'category': 'retinotopy',
#              'size_bytes': 2860254,
#              'size': '2.7 MiB',
#              'size_mib': 2.727750778198242,
#              'size_gib': 0.002663819119334221,
#              'md5': '3f5d70c150aba8adf84166ae8a419dbb',
#              'relative_path': 'data/retinotopy/TX108_2023_03_25_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_03_25',
#              'label': 'TX108_2023_03_25_trans.npz · 2.7 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_03_25_trans.npz")'}],
#   'load': {'behavior:sup_test1': 'session.load("behavior", experiment="sup_test1")',
#            'behavior:sup_train2_before_learning': 'session.load("behavior", '
#                                                   'experiment="sup_train2_before_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_04_01_1',
#   'mouse': 'TX108',
#   'date': '2023-04-01',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_04_01',
#   'experiments': ('sup_train2_after_learning',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 4942682715,
#   'published_size': '4.6 GiB',
#   'files': [{'name': 'Beh_sup_train2_after_learning.npy',
#              'figshare_file_id': 54183866,
#              'category': 'imaging_behavior',
#              'size_bytes': 141228534,
#              'size': '134.7 MiB',
#              'size_mib': 134.68602561950684,
#              'size_gib': 0.13152932189404964,
#              'md5': 'a1e4bcb573c7b1646daf8830648f4ef6',
#              'relative_path': 'data/beh/Beh_sup_train2_after_learning.npy',
#              'experiment': 'sup_train2_after_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train2_after_learning.npy · 134.7 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train2_after_learning.npy")'},
#             {'name': 'TX108_2023_04_01_1_neural_data.npy',
#              'figshare_file_id': 54184646,
#              'category': 'full_neural',
#              'size_bytes': 4662716053,
#              'size': '4.3 GiB',
#              'size_mib': 4446.712544441223,
#              'size_gib': 4.342492719180882,
#              'md5': 'e2d13aff87ae14001a5c4b51dfa2687d',
#              'relative_path': 'data/spk/TX108_2023_04_01_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_01_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_01_1_neural_data.npy · 4.3 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_01_1_neural_data.npy")'},
#             {'name': 'TX108_2023_04_01_1_SVD_dec.npy',
#              'figshare_file_id': 54866249,
#              'category': 'reduced_neural',
#              'size_bytes': 136287266,
#              'size': '130.0 MiB',
#              'size_mib': 129.97366523742676,
#              'size_gib': 0.12692740745842457,
#              'md5': 'a6bf999b328f61d27963818b72b2b470',
#              'relative_path': 'data/SVD_dec/TX108_2023_04_01_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_01_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_01_1_SVD_dec.npy · 130.0 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_01_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_04_01_trans.npz',
#              'figshare_file_id': 54184058,
#              'category': 'retinotopy',
#              'size_bytes': 2450862,
#              'size': '2.3 MiB',
#              'size_mib': 2.3373241424560547,
#              'size_gib': 0.002282543107867241,
#              'md5': 'acb6e3e8995a6881830b9bbed73bd0f2',
#              'relative_path': 'data/retinotopy/TX108_2023_04_01_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_04_01',
#              'label': 'TX108_2023_04_01_trans.npz · 2.3 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_04_01_trans.npz")'}],
#   'load': {'behavior:sup_train2_after_learning': 'session.load("behavior", '
#                                                  'experiment="sup_train2_after_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_04_04_1',
#   'mouse': 'TX108',
#   'date': '2023-04-04',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_04_04',
#   'experiments': ('sup_test2',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 6524698520,
#   'published_size': '6.1 GiB',
#   'files': [{'name': 'Beh_sup_test2.npy',
#              'figshare_file_id': 54183869,
#              'category': 'imaging_behavior',
#              'size_bytes': 161695939,
#              'size': '154.2 MiB',
#              'size_mib': 154.2052640914917,
#              'size_gib': 0.15059107821434736,
#              'md5': '67d5413083b3ffbb5f0b5ceddfd1c66b',
#              'relative_path': 'data/beh/Beh_sup_test2.npy',
#              'experiment': 'sup_test2',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_test2.npy · 154.2 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_test2.npy")'},
#             {'name': 'TX108_2023_04_04_1_neural_data.npy',
#              'figshare_file_id': 54184721,
#              'category': 'full_neural',
#              'size_bytes': 6205358993,
#              'size': '5.8 GiB',
#              'size_mib': 5917.891495704651,
#              'size_gib': 5.779190913774073,
#              'md5': 'a18234e9ca549404edb590d84aa26f83',
#              'relative_path': 'data/spk/TX108_2023_04_04_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_04_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_04_1_neural_data.npy · 5.8 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_04_1_neural_data.npy")'},
#             {'name': 'TX108_2023_04_04_1_SVD_dec.npy',
#              'figshare_file_id': 54866279,
#              'category': 'reduced_neural',
#              'size_bytes': 154887266,
#              'size': '147.7 MiB',
#              'size_mib': 147.712007522583,
#              'size_gib': 0.14425000734627247,
#              'md5': 'ef498a3a52858adcba7b1136baebce03',
#              'relative_path': 'data/SVD_dec/TX108_2023_04_04_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_04_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_04_1_SVD_dec.npy · 147.7 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_04_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_04_04_trans.npz',
#              'figshare_file_id': 54184073,
#              'category': 'retinotopy',
#              'size_bytes': 2756322,
#              'size': '2.6 MiB',
#              'size_mib': 2.628633499145508,
#              'size_gib': 0.002567024901509285,
#              'md5': 'dafe16f94a57770f1645ebd804626eba',
#              'relative_path': 'data/retinotopy/TX108_2023_04_04_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_04_04',
#              'label': 'TX108_2023_04_04_trans.npz · 2.6 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_04_04_trans.npz")'}],
#   'load': {'behavior:sup_test2': 'session.load("behavior", experiment="sup_test2")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_04_07_1',
#   'mouse': 'TX108',
#   'date': '2023-04-07',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_04_07',
#   'experiments': ('sup_test3',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 4958150867,
#   'published_size': '4.6 GiB',
#   'files': [{'name': 'Beh_sup_test3.npy',
#              'figshare_file_id': 54183872,
#              'category': 'imaging_behavior',
#              'size_bytes': 169187762,
#              'size': '161.4 MiB',
#              'size_mib': 161.35002326965332,
#              'size_gib': 0.15756838209927082,
#              'md5': 'c9f3060140564dc56518c6f56a4683bb',
#              'relative_path': 'data/beh/Beh_sup_test3.npy',
#              'experiment': 'sup_test3',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_test3.npy · 161.4 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_test3.npy")'},
#             {'name': 'TX108_2023_04_07_1_neural_data.npy',
#              'figshare_file_id': 54184643,
#              'category': 'full_neural',
#              'size_bytes': 4652948401,
#              'size': '4.3 GiB',
#              'size_mib': 4437.397385597229,
#              'size_gib': 4.333395884372294,
#              'md5': '281d7e64e39b4b8dab7c6fba17178825',
#              'relative_path': 'data/spk/TX108_2023_04_07_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_07_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_07_1_neural_data.npy · 4.3 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_07_1_neural_data.npy")'},
#             {'name': 'TX108_2023_04_07_1_SVD_dec.npy',
#              'figshare_file_id': 54866240,
#              'category': 'reduced_neural',
#              'size_bytes': 133642466,
#              'size': '127.5 MiB',
#              'size_mib': 127.45138740539551,
#              'size_gib': 0.12446424551308155,
#              'md5': '5e979c934a54ff0a62f4a90657758029',
#              'relative_path': 'data/SVD_dec/TX108_2023_04_07_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_07_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_07_1_SVD_dec.npy · 127.5 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_07_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_04_07_trans.npz',
#              'figshare_file_id': 54184067,
#              'category': 'retinotopy',
#              'size_bytes': 2372238,
#              'size': '2.3 MiB',
#              'size_mib': 2.2623424530029297,
#              'size_gib': 0.0022093188017606735,
#              'md5': '3f63205e0dac401e54ee522ecac8d180',
#              'relative_path': 'data/retinotopy/TX108_2023_04_07_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_04_07',
#              'label': 'TX108_2023_04_07_trans.npz · 2.3 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_04_07_trans.npz")'}],
#   'load': {'behavior:sup_test3': 'session.load("behavior", experiment="sup_test3")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'})]

# %%
mice_recordings = {
    category: {
      mouse: data.recordings(mouse = mouse)
    for mouse in elements
    }
  for (category, elements) in mice.items()
}
{ category: len(recordings) for (category, recordings) in mice_recordings.items() }
# Out:
# {'supervised': 5, 'unsupervised': 9, 'grating': 3, 'naive': 2}

# %%
mice_recordings['supervised']['TX108']
# Out:
# [Recording({'recording_id': 'TX108_2023_01_05_2',
#   'mouse': 'TX108',
#   'date': '2023-01-05',
#   'block': '2',
#   'retinotopy_id': 'TX108_2023_01_05',
#   'experiments': ('naive_test1',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 6941629391,
#   'published_size': '6.5 GiB',
#   'files': [{'name': 'Beh_naive_test1.npy',
#              'figshare_file_id': 54183923,
#              'category': 'imaging_behavior',
#              'size_bytes': 432561586,
#              'size': '412.5 MiB',
#              'size_mib': 412.5228748321533,
#              'size_gib': 0.4028543699532747,
#              'md5': 'c582b1937ee1917dce1512036b346ba3',
#              'relative_path': 'data/beh/Beh_naive_test1.npy',
#              'experiment': 'naive_test1',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_naive_test1.npy · 412.5 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_naive_test1.npy")'},
#             {'name': 'TX108_2023_01_05_2_neural_data.npy',
#              'figshare_file_id': 54184736,
#              'category': 'full_neural',
#              'size_bytes': 6359799389,
#              'size': '5.9 GiB',
#              'size_mib': 6065.177334785461,
#              'size_gib': 5.923024741001427,
#              'md5': '189783922d03e65f0f60683a742f6b92',
#              'relative_path': 'data/spk/TX108_2023_01_05_2_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_01_05_2',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_01_05_2_neural_data.npy · 5.9 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_01_05_2_neural_data.npy")'},
#             {'name': 'TX108_2023_01_05_2_SVD_dec.npy',
#              'figshare_file_id': 54866267,
#              'category': 'reduced_neural',
#              'size_bytes': 146799266,
#              'size': '140.0 MiB',
#              'size_mib': 139.99868965148926,
#              'size_gib': 0.13671747036278248,
#              'md5': '4c50ab3ca0984ee6024c9d06736351d6',
#              'relative_path': 'data/SVD_dec/TX108_2023_01_05_2_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_01_05_2',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_01_05_2_SVD_dec.npy · 140.0 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_01_05_2_SVD_dec.npy")'},
#             {'name': 'TX108_2023_01_05_trans.npz',
#              'figshare_file_id': 54184043,
#              'category': 'retinotopy',
#              'size_bytes': 2469150,
#              'size': '2.4 MiB',
#              'size_mib': 2.354764938354492,
#              'size_gib': 0.0022995751351118088,
#              'md5': '475df8c485a8a3dc63fcffbfb583d922',
#              'relative_path': 'data/retinotopy/TX108_2023_01_05_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_01_05',
#              'label': 'TX108_2023_01_05_trans.npz · 2.4 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_01_05_trans.npz")'}],
#   'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_03_13_1',
#   'mouse': 'TX108',
#   'date': '2023-03-13',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_03_13',
#   'experiments': ('sup_train1_before_learning',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 8162717957,
#   'published_size': '7.6 GiB',
#   'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#              'figshare_file_id': 54183863,
#              'category': 'imaging_behavior',
#              'size_bytes': 124559852,
#              'size': '118.8 MiB',
#              'size_mib': 118.78953170776367,
#              'size_gib': 0.11600540205836296,
#              'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#              'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#              'experiment': 'sup_train1_before_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#             {'name': 'TX108_2023_03_13_1_neural_data.npy',
#              'figshare_file_id': 54184787,
#              'category': 'full_neural',
#              'size_bytes': 7861517081,
#              'size': '7.3 GiB',
#              'size_mib': 7497.326928138733,
#              'size_gib': 7.321608328260481,
#              'md5': '7198e6b915ab46c6d3e3ffd69603853a',
#              'relative_path': 'data/spk/TX108_2023_03_13_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_13_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_13_1_neural_data.npy · 7.3 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_13_1_neural_data.npy")'},
#             {'name': 'TX108_2023_03_13_1_SVD_dec.npy',
#              'figshare_file_id': 54866285,
#              'category': 'reduced_neural',
#              'size_bytes': 173562466,
#              'size': '165.5 MiB',
#              'size_mib': 165.522066116333,
#              'size_gib': 0.16164264269173145,
#              'md5': '66e74de2fa04b44473cb022fc218f369',
#              'relative_path': 'data/SVD_dec/TX108_2023_03_13_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_13_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_13_1_SVD_dec.npy · 165.5 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_13_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_03_13_trans.npz',
#              'figshare_file_id': 54184049,
#              'category': 'retinotopy',
#              'size_bytes': 3078558,
#              'size': '2.9 MiB',
#              'size_mib': 2.935941696166992,
#              'size_gib': 0.0028671305626630783,
#              'md5': 'ad11366cca099003be409687efb6a74c',
#              'relative_path': 'data/retinotopy/TX108_2023_03_13_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_03_13',
#              'label': 'TX108_2023_03_13_trans.npz · 2.9 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_03_13_trans.npz")'}],
#   'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                   'experiment="sup_train1_before_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_03_22_1',
#   'mouse': 'TX108',
#   'date': '2023-03-22',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_03_22',
#   'experiments': ('sup_train1_after_learning',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 6175517868,
#   'published_size': '5.8 GiB',
#   'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#              'figshare_file_id': 54183860,
#              'category': 'imaging_behavior',
#              'size_bytes': 113352887,
#              'size': '108.1 MiB',
#              'size_mib': 108.1017370223999,
#              'size_gib': 0.1055681025609374,
#              'md5': '08c7066c45c4edfb871ff29b314ba64a',
#              'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#              'experiment': 'sup_train1_after_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#             {'name': 'TX108_2023_03_22_1_neural_data.npy',
#              'figshare_file_id': 54184700,
#              'category': 'full_neural',
#              'size_bytes': 5907367193,
#              'size': '5.5 GiB',
#              'size_mib': 5633.704369544983,
#              'size_gib': 5.501664423383772,
#              'md5': '4cde6c5d3f33c3a1f5c65150c722a242',
#              'relative_path': 'data/spk/TX108_2023_03_22_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_22_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_22_1_neural_data.npy · 5.5 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_22_1_neural_data.npy")'},
#             {'name': 'TX108_2023_03_22_1_SVD_dec.npy',
#              'figshare_file_id': 54866273,
#              'category': 'reduced_neural',
#              'size_bytes': 152079266,
#              'size': '145.0 MiB',
#              'size_mib': 145.03409004211426,
#              'size_gib': 0.1416348535567522,
#              'md5': '0a933f53cbe7702b89467c66ebc07b34',
#              'relative_path': 'data/SVD_dec/TX108_2023_03_22_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_22_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_22_1_SVD_dec.npy · 145.0 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_22_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_03_22_trans.npz',
#              'figshare_file_id': 54184052,
#              'category': 'retinotopy',
#              'size_bytes': 2718522,
#              'size': '2.6 MiB',
#              'size_mib': 2.5925846099853516,
#              'size_gib': 0.00253182090818882,
#              'md5': '5083ea99f53082ef53df7fb0a1334a50',
#              'relative_path': 'data/retinotopy/TX108_2023_03_22_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_03_22',
#              'label': 'TX108_2023_03_22_trans.npz · 2.6 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_03_22_trans.npz")'}],
#   'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                  'experiment="sup_train1_after_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_03_25_1',
#   'mouse': 'TX108',
#   'date': '2023-03-25',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_03_25',
#   'experiments': ('sup_test1', 'sup_train2_before_learning'),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 5,
#   'published_bytes': 8983795993,
#   'published_size': '8.4 GiB',
#   'files': [{'name': 'Beh_sup_test1.npy',
#              'figshare_file_id': 54183875,
#              'category': 'imaging_behavior',
#              'size_bytes': 180666800,
#              'size': '172.3 MiB',
#              'size_mib': 172.2972869873047,
#              'size_gib': 0.16825906932353973,
#              'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#              'relative_path': 'data/beh/Beh_sup_test1.npy',
#              'experiment': 'sup_test1',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_test1.npy · 172.3 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_test1.npy")'},
#             {'name': 'Beh_sup_train2_before_learning.npy',
#              'figshare_file_id': 54183881,
#              'category': 'imaging_behavior',
#              'size_bytes': 180666800,
#              'size': '172.3 MiB',
#              'size_mib': 172.2972869873047,
#              'size_gib': 0.16825906932353973,
#              'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#              'relative_path': 'data/beh/Beh_sup_train2_before_learning.npy',
#              'experiment': 'sup_train2_before_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train2_before_learning.npy · 172.3 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train2_before_learning.npy")'},
#             {'name': 'TX108_2023_03_25_1_neural_data.npy',
#              'figshare_file_id': 54184793,
#              'category': 'full_neural',
#              'size_bytes': 8449969273,
#              'size': '7.9 GiB',
#              'size_mib': 8058.518670082092,
#              'size_gib': 7.869647138752043,
#              'md5': '3e87d3fcc74b2f841e4645cc78d0eac1',
#              'relative_path': 'data/spk/TX108_2023_03_25_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_25_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_25_1_neural_data.npy · 7.9 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_25_1_neural_data.npy")'},
#             {'name': 'TX108_2023_03_25_1_SVD_dec.npy',
#              'figshare_file_id': 54866288,
#              'category': 'reduced_neural',
#              'size_bytes': 169632866,
#              'size': '161.8 MiB',
#              'size_mib': 161.774507522583,
#              'size_gib': 0.15798291750252247,
#              'md5': '29900e2e23ffada97c2c5d8fecfe8858',
#              'relative_path': 'data/SVD_dec/TX108_2023_03_25_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_03_25_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_03_25_1_SVD_dec.npy · 161.8 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_03_25_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_03_25_trans.npz',
#              'figshare_file_id': 54184061,
#              'category': 'retinotopy',
#              'size_bytes': 2860254,
#              'size': '2.7 MiB',
#              'size_mib': 2.727750778198242,
#              'size_gib': 0.002663819119334221,
#              'md5': '3f5d70c150aba8adf84166ae8a419dbb',
#              'relative_path': 'data/retinotopy/TX108_2023_03_25_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_03_25',
#              'label': 'TX108_2023_03_25_trans.npz · 2.7 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_03_25_trans.npz")'}],
#   'load': {'behavior:sup_test1': 'session.load("behavior", experiment="sup_test1")',
#            'behavior:sup_train2_before_learning': 'session.load("behavior", '
#                                                   'experiment="sup_train2_before_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_04_01_1',
#   'mouse': 'TX108',
#   'date': '2023-04-01',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_04_01',
#   'experiments': ('sup_train2_after_learning',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 4942682715,
#   'published_size': '4.6 GiB',
#   'files': [{'name': 'Beh_sup_train2_after_learning.npy',
#              'figshare_file_id': 54183866,
#              'category': 'imaging_behavior',
#              'size_bytes': 141228534,
#              'size': '134.7 MiB',
#              'size_mib': 134.68602561950684,
#              'size_gib': 0.13152932189404964,
#              'md5': 'a1e4bcb573c7b1646daf8830648f4ef6',
#              'relative_path': 'data/beh/Beh_sup_train2_after_learning.npy',
#              'experiment': 'sup_train2_after_learning',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_train2_after_learning.npy · 134.7 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_train2_after_learning.npy")'},
#             {'name': 'TX108_2023_04_01_1_neural_data.npy',
#              'figshare_file_id': 54184646,
#              'category': 'full_neural',
#              'size_bytes': 4662716053,
#              'size': '4.3 GiB',
#              'size_mib': 4446.712544441223,
#              'size_gib': 4.342492719180882,
#              'md5': 'e2d13aff87ae14001a5c4b51dfa2687d',
#              'relative_path': 'data/spk/TX108_2023_04_01_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_01_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_01_1_neural_data.npy · 4.3 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_01_1_neural_data.npy")'},
#             {'name': 'TX108_2023_04_01_1_SVD_dec.npy',
#              'figshare_file_id': 54866249,
#              'category': 'reduced_neural',
#              'size_bytes': 136287266,
#              'size': '130.0 MiB',
#              'size_mib': 129.97366523742676,
#              'size_gib': 0.12692740745842457,
#              'md5': 'a6bf999b328f61d27963818b72b2b470',
#              'relative_path': 'data/SVD_dec/TX108_2023_04_01_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_01_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_01_1_SVD_dec.npy · 130.0 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_01_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_04_01_trans.npz',
#              'figshare_file_id': 54184058,
#              'category': 'retinotopy',
#              'size_bytes': 2450862,
#              'size': '2.3 MiB',
#              'size_mib': 2.3373241424560547,
#              'size_gib': 0.002282543107867241,
#              'md5': 'acb6e3e8995a6881830b9bbed73bd0f2',
#              'relative_path': 'data/retinotopy/TX108_2023_04_01_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_04_01',
#              'label': 'TX108_2023_04_01_trans.npz · 2.3 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_04_01_trans.npz")'}],
#   'load': {'behavior:sup_train2_after_learning': 'session.load("behavior", '
#                                                  'experiment="sup_train2_after_learning")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_04_04_1',
#   'mouse': 'TX108',
#   'date': '2023-04-04',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_04_04',
#   'experiments': ('sup_test2',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 6524698520,
#   'published_size': '6.1 GiB',
#   'files': [{'name': 'Beh_sup_test2.npy',
#              'figshare_file_id': 54183869,
#              'category': 'imaging_behavior',
#              'size_bytes': 161695939,
#              'size': '154.2 MiB',
#              'size_mib': 154.2052640914917,
#              'size_gib': 0.15059107821434736,
#              'md5': '67d5413083b3ffbb5f0b5ceddfd1c66b',
#              'relative_path': 'data/beh/Beh_sup_test2.npy',
#              'experiment': 'sup_test2',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_test2.npy · 154.2 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_test2.npy")'},
#             {'name': 'TX108_2023_04_04_1_neural_data.npy',
#              'figshare_file_id': 54184721,
#              'category': 'full_neural',
#              'size_bytes': 6205358993,
#              'size': '5.8 GiB',
#              'size_mib': 5917.891495704651,
#              'size_gib': 5.779190913774073,
#              'md5': 'a18234e9ca549404edb590d84aa26f83',
#              'relative_path': 'data/spk/TX108_2023_04_04_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_04_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_04_1_neural_data.npy · 5.8 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_04_1_neural_data.npy")'},
#             {'name': 'TX108_2023_04_04_1_SVD_dec.npy',
#              'figshare_file_id': 54866279,
#              'category': 'reduced_neural',
#              'size_bytes': 154887266,
#              'size': '147.7 MiB',
#              'size_mib': 147.712007522583,
#              'size_gib': 0.14425000734627247,
#              'md5': 'ef498a3a52858adcba7b1136baebce03',
#              'relative_path': 'data/SVD_dec/TX108_2023_04_04_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_04_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_04_1_SVD_dec.npy · 147.7 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_04_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_04_04_trans.npz',
#              'figshare_file_id': 54184073,
#              'category': 'retinotopy',
#              'size_bytes': 2756322,
#              'size': '2.6 MiB',
#              'size_mib': 2.628633499145508,
#              'size_gib': 0.002567024901509285,
#              'md5': 'dafe16f94a57770f1645ebd804626eba',
#              'relative_path': 'data/retinotopy/TX108_2023_04_04_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_04_04',
#              'label': 'TX108_2023_04_04_trans.npz · 2.6 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_04_04_trans.npz")'}],
#   'load': {'behavior:sup_test2': 'session.load("behavior", experiment="sup_test2")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'}),
#  Recording({'recording_id': 'TX108_2023_04_07_1',
#   'mouse': 'TX108',
#   'date': '2023-04-07',
#   'block': '1',
#   'retinotopy_id': 'TX108_2023_04_07',
#   'experiments': ('sup_test3',),
#   'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#   'published_file_count': 4,
#   'published_bytes': 4958150867,
#   'published_size': '4.6 GiB',
#   'files': [{'name': 'Beh_sup_test3.npy',
#              'figshare_file_id': 54183872,
#              'category': 'imaging_behavior',
#              'size_bytes': 169187762,
#              'size': '161.4 MiB',
#              'size_mib': 161.35002326965332,
#              'size_gib': 0.15756838209927082,
#              'md5': 'c9f3060140564dc56518c6f56a4683bb',
#              'relative_path': 'data/beh/Beh_sup_test3.npy',
#              'experiment': 'sup_test3',
#              'recording_id': None,
#              'retinotopy_id': None,
#              'label': 'Beh_sup_test3.npy · 161.4 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("Beh_sup_test3.npy")'},
#             {'name': 'TX108_2023_04_07_1_neural_data.npy',
#              'figshare_file_id': 54184643,
#              'category': 'full_neural',
#              'size_bytes': 4652948401,
#              'size': '4.3 GiB',
#              'size_mib': 4437.397385597229,
#              'size_gib': 4.333395884372294,
#              'md5': '281d7e64e39b4b8dab7c6fba17178825',
#              'relative_path': 'data/spk/TX108_2023_04_07_1_neural_data.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_07_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_07_1_neural_data.npy · 4.3 GiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_07_1_neural_data.npy")'},
#             {'name': 'TX108_2023_04_07_1_SVD_dec.npy',
#              'figshare_file_id': 54866240,
#              'category': 'reduced_neural',
#              'size_bytes': 133642466,
#              'size': '127.5 MiB',
#              'size_mib': 127.45138740539551,
#              'size_gib': 0.12446424551308155,
#              'md5': '5e979c934a54ff0a62f4a90657758029',
#              'relative_path': 'data/SVD_dec/TX108_2023_04_07_1_SVD_dec.npy',
#              'experiment': None,
#              'recording_id': 'TX108_2023_04_07_1',
#              'retinotopy_id': None,
#              'label': 'TX108_2023_04_07_1_SVD_dec.npy · 127.5 MiB',
#              'suffix': '.npy',
#              'load': 'data.load("TX108_2023_04_07_1_SVD_dec.npy")'},
#             {'name': 'TX108_2023_04_07_trans.npz',
#              'figshare_file_id': 54184067,
#              'category': 'retinotopy',
#              'size_bytes': 2372238,
#              'size': '2.3 MiB',
#              'size_mib': 2.2623424530029297,
#              'size_gib': 0.0022093188017606735,
#              'md5': '3f63205e0dac401e54ee522ecac8d180',
#              'relative_path': 'data/retinotopy/TX108_2023_04_07_trans.npz',
#              'experiment': None,
#              'recording_id': None,
#              'retinotopy_id': 'TX108_2023_04_07',
#              'label': 'TX108_2023_04_07_trans.npz · 2.3 MiB',
#              'suffix': '.npz',
#              'load': 'data.load("TX108_2023_04_07_trans.npz")'}],
#   'load': {'behavior:sup_test3': 'session.load("behavior", experiment="sup_test3")',
#            'reduced_neural': 'session.load("reduced_neural")',
#            'full_neural': 'session.load("full_neural")',
#            'retinotopy': 'session.load("retinotopy")'},
#   'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#   'availability': 'mounted'})]

# %%
def files(recordings):
  return [ [ file.name for file in recording.files] for recording in recordings ]

# %%
files(mice_recordings['supervised']['TX108'])
# Out:
# [['Beh_naive_test1.npy',
#   'TX108_2023_01_05_2_SVD_dec.npy',
#   'TX108_2023_01_05_2_neural_data.npy',
#   'TX108_2023_01_05_trans.npz'],
#  ['Beh_sup_train1_before_learning.npy',
#   'TX108_2023_03_13_1_SVD_dec.npy',
#   'TX108_2023_03_13_1_neural_data.npy',
#   'TX108_2023_03_13_trans.npz'],
#  ['Beh_sup_train1_after_learning.npy',
#   'TX108_2023_03_22_1_SVD_dec.npy',
#   'TX108_2023_03_22_1_neural_data.npy',
#   'TX108_2023_03_22_trans.npz'],
#  ['Beh_sup_test1.npy',
#   'Beh_sup_train2_before_learning.npy',
#   'TX108_2023_03_25_1_SVD_dec.npy',
#   'TX108_2023_03_25_1_neural_data.npy',
#   'TX108_2023_03_25_trans.npz'],
#  ['Beh_sup_train2_after_learning.npy',
#   'TX108_2023_04_01_1_SVD_dec.npy',
#   'TX108_2023_04_01_1_neural_data.npy',
#   'TX108_2023_04_01_trans.npz'],
#  ['Beh_sup_test2.npy',
#   'TX108_2023_04_04_1_SVD_dec.npy',
#   'TX108_2023_04_04_1_neural_data.npy',
#   'TX108_2023_04_04_trans.npz'],
#  ['Beh_sup_test3.npy',
#   'TX108_2023_04_07_1_SVD_dec.npy',
#   'TX108_2023_04_07_1_neural_data.npy',
#   'TX108_2023_04_07_trans.npz']]

# %%
files(mice_recordings['naive']['TX124'])
# Out:
# [['Beh_naive_test1.npy',
#   'Beh_naive_test2.npy',
#   'TX124_2023_12_23_1_SVD_dec.npy',
#   'TX124_2023_12_23_1_neural_data.npy',
#   'TX124_2023_12_23_trans.npz'],
#  ['Beh_naive_test3.npy',
#   'TX124_2023_12_24_1_SVD_dec.npy',
#   'TX124_2023_12_24_1_neural_data.npy',
#   'TX124_2023_12_24_trans.npz'],
#  ['Beh_naive_test3.npy',
#   'TX124_2023_12_26_1_SVD_dec.npy',
#   'TX124_2023_12_26_1_neural_data.npy',
#   'TX124_2023_12_26_trans.npz']]

# %%
files(mice_recordings['naive']['TX140'])
# Out:
# [['Beh_naive_test1.npy',
#   'Beh_naive_test2.npy',
#   'TX140_2024_05_31_1_SVD_dec.npy',
#   'TX140_2024_05_31_1_neural_data.npy',
#   'TX140_2024_05_31_trans.npz']]

# %%
train1_labels = {
    "supervised": (
        "sup_train1_before_learning",
        "sup_train1_after_learning",
    ),
    "unsupervised": (
        "unsup_train1_before_learning",
        "unsup_train1_after_learning",
    ),
    "grating": (
        "train1_before_grating",
        "train1_after_grating",
    ),
    "naive": (
        "naive_test1",
    ),
}

# %%
mice_recordings
# Out:
# {'supervised': {'TX108': [Recording({'recording_id': 'TX108_2023_01_05_2',
#     'mouse': 'TX108',
#     'date': '2023-01-05',
#     'block': '2',
#     'retinotopy_id': 'TX108_2023_01_05',
#     'experiments': ('naive_test1',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 6941629391,
#     'published_size': '6.5 GiB',
#     'files': [{'name': 'Beh_naive_test1.npy',
#                'figshare_file_id': 54183923,
#                'category': 'imaging_behavior',
#                'size_bytes': 432561586,
#                'size': '412.5 MiB',
#                'size_mib': 412.5228748321533,
#                'size_gib': 0.4028543699532747,
#                'md5': 'c582b1937ee1917dce1512036b346ba3',
#                'relative_path': 'data/beh/Beh_naive_test1.npy',
#                'experiment': 'naive_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test1.npy · 412.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test1.npy")'},
#               {'name': 'TX108_2023_01_05_2_neural_data.npy',
#                'figshare_file_id': 54184736,
#                'category': 'full_neural',
#                'size_bytes': 6359799389,
#                'size': '5.9 GiB',
#                'size_mib': 6065.177334785461,
#                'size_gib': 5.923024741001427,
#                'md5': '189783922d03e65f0f60683a742f6b92',
#                'relative_path': 'data/spk/TX108_2023_01_05_2_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_01_05_2',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_01_05_2_neural_data.npy · 5.9 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_01_05_2_neural_data.npy")'},
#               {'name': 'TX108_2023_01_05_2_SVD_dec.npy',
#                'figshare_file_id': 54866267,
#                'category': 'reduced_neural',
#                'size_bytes': 146799266,
#                'size': '140.0 MiB',
#                'size_mib': 139.99868965148926,
#                'size_gib': 0.13671747036278248,
#                'md5': '4c50ab3ca0984ee6024c9d06736351d6',
#                'relative_path': 'data/SVD_dec/TX108_2023_01_05_2_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_01_05_2',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_01_05_2_SVD_dec.npy · 140.0 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_01_05_2_SVD_dec.npy")'},
#               {'name': 'TX108_2023_01_05_trans.npz',
#                'figshare_file_id': 54184043,
#                'category': 'retinotopy',
#                'size_bytes': 2469150,
#                'size': '2.4 MiB',
#                'size_mib': 2.354764938354492,
#                'size_gib': 0.0022995751351118088,
#                'md5': '475df8c485a8a3dc63fcffbfb583d922',
#                'relative_path': 'data/retinotopy/TX108_2023_01_05_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_01_05',
#                'label': 'TX108_2023_01_05_trans.npz · 2.4 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_01_05_trans.npz")'}],
#     'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX108_2023_03_13_1',
#     'mouse': 'TX108',
#     'date': '2023-03-13',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_03_13',
#     'experiments': ('sup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 8162717957,
#     'published_size': '7.6 GiB',
#     'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#                'figshare_file_id': 54183863,
#                'category': 'imaging_behavior',
#                'size_bytes': 124559852,
#                'size': '118.8 MiB',
#                'size_mib': 118.78953170776367,
#                'size_gib': 0.11600540205836296,
#                'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#                'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#                'experiment': 'sup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#               {'name': 'TX108_2023_03_13_1_neural_data.npy',
#                'figshare_file_id': 54184787,
#                'category': 'full_neural',
#                'size_bytes': 7861517081,
#                'size': '7.3 GiB',
#                'size_mib': 7497.326928138733,
#                'size_gib': 7.321608328260481,
#                'md5': '7198e6b915ab46c6d3e3ffd69603853a',
#                'relative_path': 'data/spk/TX108_2023_03_13_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_13_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_13_1_neural_data.npy · 7.3 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_13_1_neural_data.npy")'},
#               {'name': 'TX108_2023_03_13_1_SVD_dec.npy',
#                'figshare_file_id': 54866285,
#                'category': 'reduced_neural',
#                'size_bytes': 173562466,
#                'size': '165.5 MiB',
#                'size_mib': 165.522066116333,
#                'size_gib': 0.16164264269173145,
#                'md5': '66e74de2fa04b44473cb022fc218f369',
#                'relative_path': 'data/SVD_dec/TX108_2023_03_13_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_13_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_13_1_SVD_dec.npy · 165.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_13_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_03_13_trans.npz',
#                'figshare_file_id': 54184049,
#                'category': 'retinotopy',
#                'size_bytes': 3078558,
#                'size': '2.9 MiB',
#                'size_mib': 2.935941696166992,
#                'size_gib': 0.0028671305626630783,
#                'md5': 'ad11366cca099003be409687efb6a74c',
#                'relative_path': 'data/retinotopy/TX108_2023_03_13_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_03_13',
#                'label': 'TX108_2023_03_13_trans.npz · 2.9 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_03_13_trans.npz")'}],
#     'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX108_2023_03_22_1',
#     'mouse': 'TX108',
#     'date': '2023-03-22',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_03_22',
#     'experiments': ('sup_train1_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 6175517868,
#     'published_size': '5.8 GiB',
#     'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#                'figshare_file_id': 54183860,
#                'category': 'imaging_behavior',
#                'size_bytes': 113352887,
#                'size': '108.1 MiB',
#                'size_mib': 108.1017370223999,
#                'size_gib': 0.1055681025609374,
#                'md5': '08c7066c45c4edfb871ff29b314ba64a',
#                'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#                'experiment': 'sup_train1_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#               {'name': 'TX108_2023_03_22_1_neural_data.npy',
#                'figshare_file_id': 54184700,
#                'category': 'full_neural',
#                'size_bytes': 5907367193,
#                'size': '5.5 GiB',
#                'size_mib': 5633.704369544983,
#                'size_gib': 5.501664423383772,
#                'md5': '4cde6c5d3f33c3a1f5c65150c722a242',
#                'relative_path': 'data/spk/TX108_2023_03_22_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_22_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_22_1_neural_data.npy · 5.5 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_22_1_neural_data.npy")'},
#               {'name': 'TX108_2023_03_22_1_SVD_dec.npy',
#                'figshare_file_id': 54866273,
#                'category': 'reduced_neural',
#                'size_bytes': 152079266,
#                'size': '145.0 MiB',
#                'size_mib': 145.03409004211426,
#                'size_gib': 0.1416348535567522,
#                'md5': '0a933f53cbe7702b89467c66ebc07b34',
#                'relative_path': 'data/SVD_dec/TX108_2023_03_22_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_22_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_22_1_SVD_dec.npy · 145.0 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_22_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_03_22_trans.npz',
#                'figshare_file_id': 54184052,
#                'category': 'retinotopy',
#                'size_bytes': 2718522,
#                'size': '2.6 MiB',
#                'size_mib': 2.5925846099853516,
#                'size_gib': 0.00253182090818882,
#                'md5': '5083ea99f53082ef53df7fb0a1334a50',
#                'relative_path': 'data/retinotopy/TX108_2023_03_22_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_03_22',
#                'label': 'TX108_2023_03_22_trans.npz · 2.6 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_03_22_trans.npz")'}],
#     'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train1_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX108_2023_03_25_1',
#     'mouse': 'TX108',
#     'date': '2023-03-25',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_03_25',
#     'experiments': ('sup_test1', 'sup_train2_before_learning'),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 5,
#     'published_bytes': 8983795993,
#     'published_size': '8.4 GiB',
#     'files': [{'name': 'Beh_sup_test1.npy',
#                'figshare_file_id': 54183875,
#                'category': 'imaging_behavior',
#                'size_bytes': 180666800,
#                'size': '172.3 MiB',
#                'size_mib': 172.2972869873047,
#                'size_gib': 0.16825906932353973,
#                'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#                'relative_path': 'data/beh/Beh_sup_test1.npy',
#                'experiment': 'sup_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_test1.npy · 172.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_test1.npy")'},
#               {'name': 'Beh_sup_train2_before_learning.npy',
#                'figshare_file_id': 54183881,
#                'category': 'imaging_behavior',
#                'size_bytes': 180666800,
#                'size': '172.3 MiB',
#                'size_mib': 172.2972869873047,
#                'size_gib': 0.16825906932353973,
#                'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#                'relative_path': 'data/beh/Beh_sup_train2_before_learning.npy',
#                'experiment': 'sup_train2_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train2_before_learning.npy · 172.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train2_before_learning.npy")'},
#               {'name': 'TX108_2023_03_25_1_neural_data.npy',
#                'figshare_file_id': 54184793,
#                'category': 'full_neural',
#                'size_bytes': 8449969273,
#                'size': '7.9 GiB',
#                'size_mib': 8058.518670082092,
#                'size_gib': 7.869647138752043,
#                'md5': '3e87d3fcc74b2f841e4645cc78d0eac1',
#                'relative_path': 'data/spk/TX108_2023_03_25_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_25_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_25_1_neural_data.npy · 7.9 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_25_1_neural_data.npy")'},
#               {'name': 'TX108_2023_03_25_1_SVD_dec.npy',
#                'figshare_file_id': 54866288,
#                'category': 'reduced_neural',
#                'size_bytes': 169632866,
#                'size': '161.8 MiB',
#                'size_mib': 161.774507522583,
#                'size_gib': 0.15798291750252247,
#                'md5': '29900e2e23ffada97c2c5d8fecfe8858',
#                'relative_path': 'data/SVD_dec/TX108_2023_03_25_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_25_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_25_1_SVD_dec.npy · 161.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_25_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_03_25_trans.npz',
#                'figshare_file_id': 54184061,
#                'category': 'retinotopy',
#                'size_bytes': 2860254,
#                'size': '2.7 MiB',
#                'size_mib': 2.727750778198242,
#                'size_gib': 0.002663819119334221,
#                'md5': '3f5d70c150aba8adf84166ae8a419dbb',
#                'relative_path': 'data/retinotopy/TX108_2023_03_25_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_03_25',
#                'label': 'TX108_2023_03_25_trans.npz · 2.7 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_03_25_trans.npz")'}],
#     'load': {'behavior:sup_test1': 'session.load("behavior", experiment="sup_test1")',
#              'behavior:sup_train2_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train2_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX108_2023_04_01_1',
#     'mouse': 'TX108',
#     'date': '2023-04-01',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_04_01',
#     'experiments': ('sup_train2_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 4942682715,
#     'published_size': '4.6 GiB',
#     'files': [{'name': 'Beh_sup_train2_after_learning.npy',
#                'figshare_file_id': 54183866,
#                'category': 'imaging_behavior',
#                'size_bytes': 141228534,
#                'size': '134.7 MiB',
#                'size_mib': 134.68602561950684,
#                'size_gib': 0.13152932189404964,
#                'md5': 'a1e4bcb573c7b1646daf8830648f4ef6',
#                'relative_path': 'data/beh/Beh_sup_train2_after_learning.npy',
#                'experiment': 'sup_train2_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train2_after_learning.npy · 134.7 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train2_after_learning.npy")'},
#               {'name': 'TX108_2023_04_01_1_neural_data.npy',
#                'figshare_file_id': 54184646,
#                'category': 'full_neural',
#                'size_bytes': 4662716053,
#                'size': '4.3 GiB',
#                'size_mib': 4446.712544441223,
#                'size_gib': 4.342492719180882,
#                'md5': 'e2d13aff87ae14001a5c4b51dfa2687d',
#                'relative_path': 'data/spk/TX108_2023_04_01_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_04_01_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_04_01_1_neural_data.npy · 4.3 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_04_01_1_neural_data.npy")'},
#               {'name': 'TX108_2023_04_01_1_SVD_dec.npy',
#                'figshare_file_id': 54866249,
#                'category': 'reduced_neural',
#                'size_bytes': 136287266,
#                'size': '130.0 MiB',
#                'size_mib': 129.97366523742676,
#                'size_gib': 0.12692740745842457,
#                'md5': 'a6bf999b328f61d27963818b72b2b470',
#                'relative_path': 'data/SVD_dec/TX108_2023_04_01_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_04_01_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_04_01_1_SVD_dec.npy · 130.0 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_04_01_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_04_01_trans.npz',
#                'figshare_file_id': 54184058,
#                'category': 'retinotopy',
#                'size_bytes': 2450862,
#                'size': '2.3 MiB',
#                'size_mib': 2.3373241424560547,
#                'size_gib': 0.002282543107867241,
#                'md5': 'acb6e3e8995a6881830b9bbed73bd0f2',
#                'relative_path': 'data/retinotopy/TX108_2023_04_01_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_04_01',
#                'label': 'TX108_2023_04_01_trans.npz · 2.3 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_04_01_trans.npz")'}],
#     'load': {'behavior:sup_train2_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train2_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX108_2023_04_04_1',
#     'mouse': 'TX108',
#     'date': '2023-04-04',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_04_04',
#     'experiments': ('sup_test2',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 6524698520,
#     'published_size': '6.1 GiB',
#     'files': [{'name': 'Beh_sup_test2.npy',
#                'figshare_file_id': 54183869,
#                'category': 'imaging_behavior',
#                'size_bytes': 161695939,
#                'size': '154.2 MiB',
#                'size_mib': 154.2052640914917,
#                'size_gib': 0.15059107821434736,
#                'md5': '67d5413083b3ffbb5f0b5ceddfd1c66b',
#                'relative_path': 'data/beh/Beh_sup_test2.npy',
#                'experiment': 'sup_test2',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_test2.npy · 154.2 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_test2.npy")'},
#               {'name': 'TX108_2023_04_04_1_neural_data.npy',
#                'figshare_file_id': 54184721,
#                'category': 'full_neural',
#                'size_bytes': 6205358993,
#                'size': '5.8 GiB',
#                'size_mib': 5917.891495704651,
#                'size_gib': 5.779190913774073,
#                'md5': 'a18234e9ca549404edb590d84aa26f83',
#                'relative_path': 'data/spk/TX108_2023_04_04_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_04_04_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_04_04_1_neural_data.npy · 5.8 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_04_04_1_neural_data.npy")'},
#               {'name': 'TX108_2023_04_04_1_SVD_dec.npy',
#                'figshare_file_id': 54866279,
#                'category': 'reduced_neural',
#                'size_bytes': 154887266,
#                'size': '147.7 MiB',
#                'size_mib': 147.712007522583,
#                'size_gib': 0.14425000734627247,
#                'md5': 'ef498a3a52858adcba7b1136baebce03',
#                'relative_path': 'data/SVD_dec/TX108_2023_04_04_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_04_04_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_04_04_1_SVD_dec.npy · 147.7 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_04_04_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_04_04_trans.npz',
#                'figshare_file_id': 54184073,
#                'category': 'retinotopy',
#                'size_bytes': 2756322,
#                'size': '2.6 MiB',
#                'size_mib': 2.628633499145508,
#                'size_gib': 0.002567024901509285,
#                'md5': 'dafe16f94a57770f1645ebd804626eba',
#                'relative_path': 'data/retinotopy/TX108_2023_04_04_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_04_04',
#                'label': 'TX108_2023_04_04_trans.npz · 2.6 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_04_04_trans.npz")'}],
#     'load': {'behavior:sup_test2': 'session.load("behavior", experiment="sup_test2")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX108_2023_04_07_1',
#     'mouse': 'TX108',
#     'date': '2023-04-07',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_04_07',
#     'experiments': ('sup_test3',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 4958150867,
#     'published_size': '4.6 GiB',
#     'files': [{'name': 'Beh_sup_test3.npy',
#                'figshare_file_id': 54183872,
#                'category': 'imaging_behavior',
#                'size_bytes': 169187762,
#                'size': '161.4 MiB',
#                'size_mib': 161.35002326965332,
#                'size_gib': 0.15756838209927082,
#                'md5': 'c9f3060140564dc56518c6f56a4683bb',
#                'relative_path': 'data/beh/Beh_sup_test3.npy',
#                'experiment': 'sup_test3',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_test3.npy · 161.4 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_test3.npy")'},
#               {'name': 'TX108_2023_04_07_1_neural_data.npy',
#                'figshare_file_id': 54184643,
#                'category': 'full_neural',
#                'size_bytes': 4652948401,
#                'size': '4.3 GiB',
#                'size_mib': 4437.397385597229,
#                'size_gib': 4.333395884372294,
#                'md5': '281d7e64e39b4b8dab7c6fba17178825',
#                'relative_path': 'data/spk/TX108_2023_04_07_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_04_07_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_04_07_1_neural_data.npy · 4.3 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_04_07_1_neural_data.npy")'},
#               {'name': 'TX108_2023_04_07_1_SVD_dec.npy',
#                'figshare_file_id': 54866240,
#                'category': 'reduced_neural',
#                'size_bytes': 133642466,
#                'size': '127.5 MiB',
#                'size_mib': 127.45138740539551,
#                'size_gib': 0.12446424551308155,
#                'md5': '5e979c934a54ff0a62f4a90657758029',
#                'relative_path': 'data/SVD_dec/TX108_2023_04_07_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_04_07_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_04_07_1_SVD_dec.npy · 127.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_04_07_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_04_07_trans.npz',
#                'figshare_file_id': 54184067,
#                'category': 'retinotopy',
#                'size_bytes': 2372238,
#                'size': '2.3 MiB',
#                'size_mib': 2.2623424530029297,
#                'size_gib': 0.0022093188017606735,
#                'md5': '3f63205e0dac401e54ee522ecac8d180',
#                'relative_path': 'data/retinotopy/TX108_2023_04_07_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_04_07',
#                'label': 'TX108_2023_04_07_trans.npz · 2.3 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_04_07_trans.npz")'}],
#     'load': {'behavior:sup_test3': 'session.load("behavior", experiment="sup_test3")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})],
#   'TX109': [Recording({'recording_id': 'TX109_2023_03_16_1',
#     'mouse': 'TX109',
#     'date': '2023-03-16',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_03_16',
#     'experiments': ('naive_test1',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 10589755495,
#     'published_size': '9.9 GiB',
#     'files': [{'name': 'Beh_naive_test1.npy',
#                'figshare_file_id': 54183923,
#                'category': 'imaging_behavior',
#                'size_bytes': 432561586,
#                'size': '412.5 MiB',
#                'size_mib': 412.5228748321533,
#                'size_gib': 0.4028543699532747,
#                'md5': 'c582b1937ee1917dce1512036b346ba3',
#                'relative_path': 'data/beh/Beh_naive_test1.npy',
#                'experiment': 'naive_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test1.npy · 412.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test1.npy")'},
#               {'name': 'TX109_2023_03_16_1_neural_data.npy',
#                'figshare_file_id': 54184799,
#                'category': 'full_neural',
#                'size_bytes': 9970697353,
#                'size': '9.3 GiB',
#                'size_mib': 9508.797982215881,
#                'size_gib': 9.285935529507697,
#                'md5': '04665840e42c799c268acf4c75f838bd',
#                'relative_path': 'data/spk/TX109_2023_03_16_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_03_16_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_03_16_1_neural_data.npy · 9.3 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_03_16_1_neural_data.npy")'},
#               {'name': 'TX109_2023_03_16_1_SVD_dec.npy',
#                'figshare_file_id': 54866312,
#                'category': 'reduced_neural',
#                'size_bytes': 183418466,
#                'size': '174.9 MiB',
#                'size_mib': 174.921480178833,
#                'size_gib': 0.1708217579871416,
#                'md5': '8aefb4ef058c783120bdc0fb317cb78d',
#                'relative_path': 'data/SVD_dec/TX109_2023_03_16_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_03_16_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_03_16_1_SVD_dec.npy · 174.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_03_16_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_03_16_trans.npz',
#                'figshare_file_id': 54184076,
#                'category': 'retinotopy',
#                'size_bytes': 3078090,
#                'size': '2.9 MiB',
#                'size_mib': 2.935495376586914,
#                'size_gib': 0.0028666947036981583,
#                'md5': '84ee4896005ee1096095baaf0397916f',
#                'relative_path': 'data/retinotopy/TX109_2023_03_16_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_03_16',
#                'label': 'TX109_2023_03_16_trans.npz · 2.9 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_03_16_trans.npz")'}],
#     'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_03_27_1',
#     'mouse': 'TX109',
#     'date': '2023-03-27',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_03_27',
#     'experiments': ('sup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 3964132329,
#     'published_size': '3.7 GiB',
#     'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#                'figshare_file_id': 54183863,
#                'category': 'imaging_behavior',
#                'size_bytes': 124559852,
#                'size': '118.8 MiB',
#                'size_mib': 118.78953170776367,
#                'size_gib': 0.11600540205836296,
#                'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#                'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#                'experiment': 'sup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#               {'name': 'TX109_2023_03_27_1_neural_data.npy',
#                'figshare_file_id': 54184598,
#                'category': 'full_neural',
#                'size_bytes': 3712137473,
#                'size': '3.5 GiB',
#                'size_mib': 3540.1701669692993,
#                'size_gib': 3.4571974286809564,
#                'md5': 'd8fd40b04b883aade63818031236ac65',
#                'relative_path': 'data/spk/TX109_2023_03_27_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_03_27_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_03_27_1_neural_data.npy · 3.5 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_03_27_1_neural_data.npy")'},
#               {'name': 'TX109_2023_03_27_1_SVD_dec.npy',
#                'figshare_file_id': 54866204,
#                'category': 'reduced_neural',
#                'size_bytes': 125143262,
#                'size': '119.3 MiB',
#                'size_mib': 119.34591484069824,
#                'size_gib': 0.11654874496161938,
#                'md5': 'd2191482783b70b27a1d4a6cc79ad507',
#                'relative_path': 'data/SVD_dec/TX109_2023_03_27_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_03_27_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_03_27_1_SVD_dec.npy · 119.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_03_27_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_03_27_trans.npz',
#                'figshare_file_id': 54184085,
#                'category': 'retinotopy',
#                'size_bytes': 2291742,
#                'size': '2.2 MiB',
#                'size_mib': 2.185575485229492,
#                'size_gib': 0.002134351059794426,
#                'md5': 'd5808278e74325de72f6ff67b5d93c38',
#                'relative_path': 'data/retinotopy/TX109_2023_03_27_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_03_27',
#                'label': 'TX109_2023_03_27_trans.npz · 2.2 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_03_27_trans.npz")'}],
#     'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_04_07_1',
#     'mouse': 'TX109',
#     'date': '2023-04-07',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_04_07',
#     'experiments': ('sup_train1_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 7465626308,
#     'published_size': '7.0 GiB',
#     'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#                'figshare_file_id': 54183860,
#                'category': 'imaging_behavior',
#                'size_bytes': 113352887,
#                'size': '108.1 MiB',
#                'size_mib': 108.1017370223999,
#                'size_gib': 0.1055681025609374,
#                'md5': '08c7066c45c4edfb871ff29b314ba64a',
#                'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#                'experiment': 'sup_train1_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#               {'name': 'TX109_2023_04_07_1_neural_data.npy',
#                'figshare_file_id': 54184775,
#                'category': 'full_neural',
#                'size_bytes': 7173684941,
#                'size': '6.7 GiB',
#                'size_mib': 6841.359082221985,
#                'size_gib': 6.681014728732407,
#                'md5': 'b6a44ef7ff410d8d711808afa533815c',
#                'relative_path': 'data/spk/TX109_2023_04_07_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_04_07_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_04_07_1_neural_data.npy · 6.7 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_04_07_1_neural_data.npy")'},
#               {'name': 'TX109_2023_04_07_1_SVD_dec.npy',
#                'figshare_file_id': 54866318,
#                'category': 'reduced_neural',
#                'size_bytes': 175362466,
#                'size': '167.2 MiB',
#                'size_mib': 167.23867988586426,
#                'size_gib': 0.16331902332603931,
#                'md5': '805f141dec3a536abaf0015d837ab049',
#                'relative_path': 'data/SVD_dec/TX109_2023_04_07_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_04_07_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_04_07_1_SVD_dec.npy · 167.2 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_04_07_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_04_07_trans.npz',
#                'figshare_file_id': 54184091,
#                'category': 'retinotopy',
#                'size_bytes': 3226014,
#                'size': '3.1 MiB',
#                'size_mib': 3.076566696166992,
#                'size_gib': 0.0030044596642255783,
#                'md5': '2258c5a2bdd9706ba023fc14cc18a353',
#                'relative_path': 'data/retinotopy/TX109_2023_04_07_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_04_07',
#                'label': 'TX109_2023_04_07_trans.npz · 3.1 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_04_07_trans.npz")'}],
#     'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train1_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_04_18_1',
#     'mouse': 'TX109',
#     'date': '2023-04-18',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_04_18',
#     'experiments': ('sup_test1', 'sup_train2_before_learning'),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 5,
#     'published_bytes': 6314070661,
#     'published_size': '5.9 GiB',
#     'files': [{'name': 'Beh_sup_test1.npy',
#                'figshare_file_id': 54183875,
#                'category': 'imaging_behavior',
#                'size_bytes': 180666800,
#                'size': '172.3 MiB',
#                'size_mib': 172.2972869873047,
#                'size_gib': 0.16825906932353973,
#                'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#                'relative_path': 'data/beh/Beh_sup_test1.npy',
#                'experiment': 'sup_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_test1.npy · 172.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_test1.npy")'},
#               {'name': 'Beh_sup_train2_before_learning.npy',
#                'figshare_file_id': 54183881,
#                'category': 'imaging_behavior',
#                'size_bytes': 180666800,
#                'size': '172.3 MiB',
#                'size_mib': 172.2972869873047,
#                'size_gib': 0.16825906932353973,
#                'md5': 'f8f6c3d78fb17b386d9c9746e4cf821c',
#                'relative_path': 'data/beh/Beh_sup_train2_before_learning.npy',
#                'experiment': 'sup_train2_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train2_before_learning.npy · 172.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train2_before_learning.npy")'},
#               {'name': 'TX109_2023_04_18_1_neural_data.npy',
#                'figshare_file_id': 54184694,
#                'category': 'full_neural',
#                'size_bytes': 5788643029,
#                'size': '5.4 GiB',
#                'size_mib': 5520.480183601379,
#                'size_gib': 5.391093929298222,
#                'md5': 'e5e5130d9f16d446592d9e908a4d73a4',
#                'relative_path': 'data/spk/TX109_2023_04_18_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_04_18_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_04_18_1_neural_data.npy · 5.4 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_04_18_1_neural_data.npy")'},
#               {'name': 'TX109_2023_04_18_1_SVD_dec.npy',
#                'figshare_file_id': 54866306,
#                'category': 'reduced_neural',
#                'size_bytes': 161093666,
#                'size': '153.6 MiB',
#                'size_mib': 153.63089179992676,
#                'size_gib': 0.15003016777336597,
#                'md5': '101b7bf2307fe0196c04d4c42cbbaca4',
#                'relative_path': 'data/SVD_dec/TX109_2023_04_18_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_04_18_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_04_18_1_SVD_dec.npy · 153.6 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_04_18_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_04_18_trans.npz',
#                'figshare_file_id': 54184097,
#                'category': 'retinotopy',
#                'size_bytes': 3000366,
#                'size': '2.9 MiB',
#                'size_mib': 2.8613719940185547,
#                'size_gib': 0.002794308587908745,
#                'md5': '85fc6357a55d316509f70ac2b0403732',
#                'relative_path': 'data/retinotopy/TX109_2023_04_18_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_04_18',
#                'label': 'TX109_2023_04_18_trans.npz · 2.9 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_04_18_trans.npz")'}],
#     'load': {'behavior:sup_test1': 'session.load("behavior", experiment="sup_test1")',
#              'behavior:sup_train2_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train2_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_05_12_1',
#     'mouse': 'TX109',
#     'date': '2023-05-12',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_05_12',
#     'experiments': ('sup_train2_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 5729342451,
#     'published_size': '5.3 GiB',
#     'files': [{'name': 'Beh_sup_train2_after_learning.npy',
#                'figshare_file_id': 54183866,
#                'category': 'imaging_behavior',
#                'size_bytes': 141228534,
#                'size': '134.7 MiB',
#                'size_mib': 134.68602561950684,
#                'size_gib': 0.13152932189404964,
#                'md5': 'a1e4bcb573c7b1646daf8830648f4ef6',
#                'relative_path': 'data/beh/Beh_sup_train2_after_learning.npy',
#                'experiment': 'sup_train2_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train2_after_learning.npy · 134.7 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train2_after_learning.npy")'},
#               {'name': 'TX109_2023_05_12_1_neural_data.npy',
#                'figshare_file_id': 54184688,
#                'category': 'full_neural',
#                'size_bytes': 5440470277,
#                'size': '5.1 GiB',
#                'size_mib': 5188.436772346497,
#                'size_gib': 5.066832785494626,
#                'md5': '562090e8dbe4a9db88fa132de3e3dc52',
#                'relative_path': 'data/spk/TX109_2023_05_12_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_05_12_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_05_12_1_neural_data.npy · 5.1 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_05_12_1_neural_data.npy")'},
#               {'name': 'TX109_2023_05_12_1_SVD_dec.npy',
#                'figshare_file_id': 54866276,
#                'category': 'reduced_neural',
#                'size_bytes': 145061666,
#                'size': '138.3 MiB',
#                'size_mib': 138.34158515930176,
#                'size_gib': 0.13509920425713062,
#                'md5': '2334386cdb37214b5cd03b2e4d87ce59',
#                'relative_path': 'data/SVD_dec/TX109_2023_05_12_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_05_12_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_05_12_1_SVD_dec.npy · 138.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_05_12_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_05_12_trans.npz',
#                'figshare_file_id': 54184100,
#                'category': 'retinotopy',
#                'size_bytes': 2581974,
#                'size': '2.5 MiB',
#                'size_mib': 2.462362289428711,
#                'size_gib': 0.0024046506732702255,
#                'md5': '0349f03cf226456a8267e1cc3554ac4d',
#                'relative_path': 'data/retinotopy/TX109_2023_05_12_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_05_12',
#                'label': 'TX109_2023_05_12_trans.npz · 2.5 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_05_12_trans.npz")'}],
#     'load': {'behavior:sup_train2_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train2_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_05_13_1',
#     'mouse': 'TX109',
#     'date': '2023-05-13',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_05_13',
#     'experiments': ('sup_test2',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 7117989688,
#     'published_size': '6.6 GiB',
#     'files': [{'name': 'Beh_sup_test2.npy',
#                'figshare_file_id': 54183869,
#                'category': 'imaging_behavior',
#                'size_bytes': 161695939,
#                'size': '154.2 MiB',
# ...
#                'category': 'imaging_behavior',
#                'size_bytes': 432561586,
#                'size': '412.5 MiB',
#                'size_mib': 412.5228748321533,
#                'size_gib': 0.4028543699532747,
#                'md5': 'c582b1937ee1917dce1512036b346ba3',
#                'relative_path': 'data/beh/Beh_naive_test1.npy',
#                'experiment': 'naive_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test1.npy · 412.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test1.npy")'},
#               {'name': 'Beh_naive_test2.npy',
#                'figshare_file_id': 54183908,
#                'category': 'imaging_behavior',
#                'size_bytes': 286584765,
#                'size': '273.3 MiB',
#                'size_mib': 273.3085298538208,
#                'size_gib': 0.2669028611853719,
#                'md5': 'b622db42667fb01b433eef841dd58599',
#                'relative_path': 'data/beh/Beh_naive_test2.npy',
#                'experiment': 'naive_test2',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test2.npy · 273.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test2.npy")'},
#               {'name': 'TX124_2023_12_23_1_neural_data.npy',
#                'figshare_file_id': 54184490,
#                'category': 'full_neural',
#                'size_bytes': 1910749885,
#                'size': '1.8 GiB',
#                'size_mib': 1822.2330904006958,
#                'size_gib': 1.7795245023444295,
#                'md5': 'ff5ffca5dc8b1c41f3bd1c8cb4e4f153',
#                'relative_path': 'data/spk/TX124_2023_12_23_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_23_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_23_1_neural_data.npy · 1.8 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_23_1_neural_data.npy")'},
#               {'name': 'TX124_2023_12_23_1_SVD_dec.npy',
#                'figshare_file_id': 54866066,
#                'category': 'reduced_neural',
#                'size_bytes': 70364062,
#                'size': '67.1 MiB',
#                'size_mib': 67.10439872741699,
#                'size_gib': 0.06553163938224316,
#                'md5': '8413a4248c40f94cfff8e45b84cb6b06',
#                'relative_path': 'data/SVD_dec/TX124_2023_12_23_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_23_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_23_1_SVD_dec.npy · 67.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_23_1_SVD_dec.npy")'},
#               {'name': 'TX124_2023_12_23_trans.npz',
#                'figshare_file_id': 54184127,
#                'category': 'retinotopy',
#                'size_bytes': 879030,
#                'size': '858.4 KiB',
#                'size_mib': 0.8383083343505859,
#                'size_gib': 0.0008186604827642441,
#                'md5': 'a46a0315fd4ebff958b63cbc0dd3f3d0',
#                'relative_path': 'data/retinotopy/TX124_2023_12_23_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX124_2023_12_23',
#                'label': 'TX124_2023_12_23_trans.npz · 858.4 KiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX124_2023_12_23_trans.npz")'}],
#     'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#              'behavior:naive_test2': 'session.load("behavior", experiment="naive_test2")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX124_2023_12_24_1',
#     'mouse': 'TX124',
#     'date': '2023-12-24',
#     'block': '1',
#     'retinotopy_id': 'TX124_2023_12_24',
#     'experiments': ('naive_test3',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 2012994898,
#     'published_size': '1.9 GiB',
#     'files': [{'name': 'Beh_naive_test3.npy',
#                'figshare_file_id': 54183926,
#                'category': 'imaging_behavior',
#                'size_bytes': 430048721,
#                'size': '410.1 MiB',
#                'size_mib': 410.12642002105713,
#                'size_gib': 0.4005140820518136,
#                'md5': '6261f3c6f0da26630522ca6d0724e4a9',
#                'relative_path': 'data/beh/Beh_naive_test3.npy',
#                'experiment': 'naive_test3',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test3.npy · 410.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test3.npy")'},
#               {'name': 'TX124_2023_12_24_1_neural_data.npy',
#                'figshare_file_id': 54184460,
#                'category': 'full_neural',
#                'size_bytes': 1519738781,
#                'size': '1.4 GiB',
#                'size_mib': 1449.3358430862427,
#                'size_gib': 1.4153670342639089,
#                'md5': '23ce3e823d5eb8c10aac9fce1e29f7a1',
#                'relative_path': 'data/spk/TX124_2023_12_24_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_24_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_24_1_neural_data.npy · 1.4 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_24_1_neural_data.npy")'},
#               {'name': 'TX124_2023_12_24_1_SVD_dec.npy',
#                'figshare_file_id': 54866042,
#                'category': 'reduced_neural',
#                'size_bytes': 62466462,
#                'size': '59.6 MiB',
#                'size_mib': 59.57266044616699,
#                'size_gib': 0.05817642621695995,
#                'md5': '60fad2f997348362b09f1fc9acf440df',
#                'relative_path': 'data/SVD_dec/TX124_2023_12_24_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_24_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_24_1_SVD_dec.npy · 59.6 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_24_1_SVD_dec.npy")'},
#               {'name': 'TX124_2023_12_24_trans.npz',
#                'figshare_file_id': 54184130,
#                'category': 'retinotopy',
#                'size_bytes': 740934,
#                'size': '723.6 KiB',
#                'size_mib': 0.7066097259521484,
#                'size_gib': 0.000690048560500145,
#                'md5': '88b2f745771d3a0bccbf359649834a43',
#                'relative_path': 'data/retinotopy/TX124_2023_12_24_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX124_2023_12_24',
#                'label': 'TX124_2023_12_24_trans.npz · 723.6 KiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX124_2023_12_24_trans.npz")'}],
#     'load': {'behavior:naive_test3': 'session.load("behavior", experiment="naive_test3")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX124_2023_12_26_1',
#     'mouse': 'TX124',
#     'date': '2023-12-26',
#     'block': '1',
#     'retinotopy_id': 'TX124_2023_12_26',
#     'experiments': ('naive_test3',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 2120272418,
#     'published_size': '2.0 GiB',
#     'files': [{'name': 'Beh_naive_test3.npy',
#                'figshare_file_id': 54183926,
#                'category': 'imaging_behavior',
#                'size_bytes': 430048721,
#                'size': '410.1 MiB',
#                'size_mib': 410.12642002105713,
#                'size_gib': 0.4005140820518136,
#                'md5': '6261f3c6f0da26630522ca6d0724e4a9',
#                'relative_path': 'data/beh/Beh_naive_test3.npy',
#                'experiment': 'naive_test3',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test3.npy · 410.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test3.npy")'},
#               {'name': 'TX124_2023_12_26_1_neural_data.npy',
#                'figshare_file_id': 54184466,
#                'category': 'full_neural',
#                'size_bytes': 1624267257,
#                'size': '1.5 GiB',
#                'size_mib': 1549.0219659805298,
#                'size_gib': 1.5127167636528611,
#                'md5': 'ef36aca83ca1c541f1267fd5d10c86f3',
#                'relative_path': 'data/spk/TX124_2023_12_26_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_26_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_26_1_neural_data.npy · 1.5 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_26_1_neural_data.npy")'},
#               {'name': 'TX124_2023_12_26_1_SVD_dec.npy',
#                'figshare_file_id': 54866051,
#                'category': 'reduced_neural',
#                'size_bytes': 65120862,
#                'size': '62.1 MiB',
#                'size_mib': 62.10409355163574,
#                'size_gib': 0.06064852885901928,
#                'md5': '0ddd173c2ab4e729aaa1eb45c1f932f7',
#                'relative_path': 'data/SVD_dec/TX124_2023_12_26_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_26_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_26_1_SVD_dec.npy · 62.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_26_1_SVD_dec.npy")'},
#               {'name': 'TX124_2023_12_26_trans.npz',
#                'figshare_file_id': 54184133,
#                'category': 'retinotopy',
#                'size_bytes': 835578,
#                'size': '816.0 KiB',
#                'size_mib': 0.7968692779541016,
#                'size_gib': 0.0007781926542520523,
#                'md5': '60aa86c3f119d71eeb9ec19250c57b79',
#                'relative_path': 'data/retinotopy/TX124_2023_12_26_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX124_2023_12_26',
#                'label': 'TX124_2023_12_26_trans.npz · 816.0 KiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX124_2023_12_26_trans.npz")'}],
#     'load': {'behavior:naive_test3': 'session.load("behavior", experiment="naive_test3")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})],
#   'TX140': [Recording({'recording_id': 'TX140_2024_05_31_1',
#     'mouse': 'TX140',
#     'date': '2024-05-31',
#     'block': '1',
#     'retinotopy_id': 'TX140_2024_05_31',
#     'experiments': ('naive_test1', 'naive_test2'),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 5,
#     'published_bytes': 5822824808,
#     'published_size': '5.4 GiB',
#     'files': [{'name': 'Beh_naive_test1.npy',
#                'figshare_file_id': 54183923,
#                'category': 'imaging_behavior',
#                'size_bytes': 432561586,
#                'size': '412.5 MiB',
#                'size_mib': 412.5228748321533,
#                'size_gib': 0.4028543699532747,
#                'md5': 'c582b1937ee1917dce1512036b346ba3',
#                'relative_path': 'data/beh/Beh_naive_test1.npy',
#                'experiment': 'naive_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test1.npy · 412.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test1.npy")'},
#               {'name': 'Beh_naive_test2.npy',
#                'figshare_file_id': 54183908,
#                'category': 'imaging_behavior',
#                'size_bytes': 286584765,
#                'size': '273.3 MiB',
#                'size_mib': 273.3085298538208,
#                'size_gib': 0.2669028611853719,
#                'md5': 'b622db42667fb01b433eef841dd58599',
#                'relative_path': 'data/beh/Beh_naive_test2.npy',
#                'experiment': 'naive_test2',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test2.npy · 273.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test2.npy")'},
#               {'name': 'TX140_2024_05_31_1_neural_data.npy',
#                'figshare_file_id': 54184667,
#                'category': 'full_neural',
#                'size_bytes': 4982581157,
#                'size': '4.6 GiB',
#                'size_mib': 4751.759678840637,
#                'size_gib': 4.64039031136781,
#                'md5': '267d3e0660b3d6306ecb8846cfe15aa7',
#                'relative_path': 'data/spk/TX140_2024_05_31_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX140_2024_05_31_1',
#                'retinotopy_id': None,
#                'label': 'TX140_2024_05_31_1_neural_data.npy · 4.6 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX140_2024_05_31_1_neural_data.npy")'},
#               {'name': 'TX140_2024_05_31_1_SVD_dec.npy',
#                'figshare_file_id': 54866201,
#                'category': 'reduced_neural',
#                'size_bytes': 119320862,
#                'size': '113.8 MiB',
#                'size_mib': 113.79324150085449,
#                'size_gib': 0.11112621240317822,
#                'md5': 'beef506a82de5ba82d89b9a93a350783',
#                'relative_path': 'data/SVD_dec/TX140_2024_05_31_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX140_2024_05_31_1',
#                'retinotopy_id': None,
#                'label': 'TX140_2024_05_31_1_SVD_dec.npy · 113.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX140_2024_05_31_1_SVD_dec.npy")'},
#               {'name': 'TX140_2024_05_31_trans.npz',
#                'figshare_file_id': 54184142,
#                'category': 'retinotopy',
#                'size_bytes': 1776438,
#                'size': '1.7 MiB',
#                'size_mib': 1.694143295288086,
#                'size_gib': 0.0016544368118047714,
#                'md5': 'b36b8991596a5aab8de0ae3e6afeda72',
#                'relative_path': 'data/retinotopy/TX140_2024_05_31_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX140_2024_05_31',
#                'label': 'TX140_2024_05_31_trans.npz · 1.7 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX140_2024_05_31_trans.npz")'}],
#     'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#              'behavior:naive_test2': 'session.load("behavior", experiment="naive_test2")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})]}}

# %%
def select_recordings(category, label):
    allowed_mice = set(mice[category])

    return [
        recording
        for recording in data.recordings(experiment=label)
        if recording.mouse in allowed_mice
        and "full_neural" in recording.layers
    ]


train1_recordings = {
    category: {
        label: select_recordings(category, label)
        for label in labels
    }
    for category, labels in train1_labels.items()
}
train1_recordings
# Out:
# {'supervised': {'sup_train1_before_learning': [Recording({'recording_id': 'TX108_2023_03_13_1',
#     'mouse': 'TX108',
#     'date': '2023-03-13',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_03_13',
#     'experiments': ('sup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 8162717957,
#     'published_size': '7.6 GiB',
#     'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#                'figshare_file_id': 54183863,
#                'category': 'imaging_behavior',
#                'size_bytes': 124559852,
#                'size': '118.8 MiB',
#                'size_mib': 118.78953170776367,
#                'size_gib': 0.11600540205836296,
#                'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#                'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#                'experiment': 'sup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#               {'name': 'TX108_2023_03_13_1_neural_data.npy',
#                'figshare_file_id': 54184787,
#                'category': 'full_neural',
#                'size_bytes': 7861517081,
#                'size': '7.3 GiB',
#                'size_mib': 7497.326928138733,
#                'size_gib': 7.321608328260481,
#                'md5': '7198e6b915ab46c6d3e3ffd69603853a',
#                'relative_path': 'data/spk/TX108_2023_03_13_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_13_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_13_1_neural_data.npy · 7.3 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_13_1_neural_data.npy")'},
#               {'name': 'TX108_2023_03_13_1_SVD_dec.npy',
#                'figshare_file_id': 54866285,
#                'category': 'reduced_neural',
#                'size_bytes': 173562466,
#                'size': '165.5 MiB',
#                'size_mib': 165.522066116333,
#                'size_gib': 0.16164264269173145,
#                'md5': '66e74de2fa04b44473cb022fc218f369',
#                'relative_path': 'data/SVD_dec/TX108_2023_03_13_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_13_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_13_1_SVD_dec.npy · 165.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_13_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_03_13_trans.npz',
#                'figshare_file_id': 54184049,
#                'category': 'retinotopy',
#                'size_bytes': 3078558,
#                'size': '2.9 MiB',
#                'size_mib': 2.935941696166992,
#                'size_gib': 0.0028671305626630783,
#                'md5': 'ad11366cca099003be409687efb6a74c',
#                'relative_path': 'data/retinotopy/TX108_2023_03_13_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_03_13',
#                'label': 'TX108_2023_03_13_trans.npz · 2.9 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_03_13_trans.npz")'}],
#     'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_03_27_1',
#     'mouse': 'TX109',
#     'date': '2023-03-27',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_03_27',
#     'experiments': ('sup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 3964132329,
#     'published_size': '3.7 GiB',
#     'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#                'figshare_file_id': 54183863,
#                'category': 'imaging_behavior',
#                'size_bytes': 124559852,
#                'size': '118.8 MiB',
#                'size_mib': 118.78953170776367,
#                'size_gib': 0.11600540205836296,
#                'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#                'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#                'experiment': 'sup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#               {'name': 'TX109_2023_03_27_1_neural_data.npy',
#                'figshare_file_id': 54184598,
#                'category': 'full_neural',
#                'size_bytes': 3712137473,
#                'size': '3.5 GiB',
#                'size_mib': 3540.1701669692993,
#                'size_gib': 3.4571974286809564,
#                'md5': 'd8fd40b04b883aade63818031236ac65',
#                'relative_path': 'data/spk/TX109_2023_03_27_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_03_27_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_03_27_1_neural_data.npy · 3.5 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_03_27_1_neural_data.npy")'},
#               {'name': 'TX109_2023_03_27_1_SVD_dec.npy',
#                'figshare_file_id': 54866204,
#                'category': 'reduced_neural',
#                'size_bytes': 125143262,
#                'size': '119.3 MiB',
#                'size_mib': 119.34591484069824,
#                'size_gib': 0.11654874496161938,
#                'md5': 'd2191482783b70b27a1d4a6cc79ad507',
#                'relative_path': 'data/SVD_dec/TX109_2023_03_27_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_03_27_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_03_27_1_SVD_dec.npy · 119.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_03_27_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_03_27_trans.npz',
#                'figshare_file_id': 54184085,
#                'category': 'retinotopy',
#                'size_bytes': 2291742,
#                'size': '2.2 MiB',
#                'size_mib': 2.185575485229492,
#                'size_gib': 0.002134351059794426,
#                'md5': 'd5808278e74325de72f6ff67b5d93c38',
#                'relative_path': 'data/retinotopy/TX109_2023_03_27_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_03_27',
#                'label': 'TX109_2023_03_27_trans.npz · 2.2 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_03_27_trans.npz")'}],
#     'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX60_2021_04_10_1',
#     'mouse': 'TX60',
#     'date': '2021-04-10',
#     'block': '1',
#     'retinotopy_id': 'TX60_2021_04_10',
#     'experiments': ('sup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 4816608413,
#     'published_size': '4.5 GiB',
#     'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#                'figshare_file_id': 54183863,
#                'category': 'imaging_behavior',
#                'size_bytes': 124559852,
#                'size': '118.8 MiB',
#                'size_mib': 118.78953170776367,
#                'size_gib': 0.11600540205836296,
#                'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#                'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#                'experiment': 'sup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#               {'name': 'TX60_2021_04_10_1_neural_data.npy',
#                'figshare_file_id': 54184637,
#                'category': 'full_neural',
#                'size_bytes': 4574765705,
#                'size': '4.3 GiB',
#                'size_mib': 4362.836556434631,
#                'size_gib': 4.260582574643195,
#                'md5': '98425630ac650ccbb40c21bd1ff95ab2',
#                'relative_path': 'data/spk/TX60_2021_04_10_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX60_2021_04_10_1',
#                'retinotopy_id': None,
#                'label': 'TX60_2021_04_10_1_neural_data.npy · 4.3 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX60_2021_04_10_1_neural_data.npy")'},
#               {'name': 'TX60_2021_04_10_1_SVD_dec.npy',
#                'figshare_file_id': 54866198,
#                'category': 'reduced_neural',
#                'size_bytes': 115527262,
#                'size': '110.2 MiB',
#                'size_mib': 110.17538261413574,
#                'size_gib': 0.10759314708411694,
#                'md5': 'ab46727703cfb2248017486088fbf794',
#                'relative_path': 'data/SVD_dec/TX60_2021_04_10_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX60_2021_04_10_1',
#                'retinotopy_id': None,
#                'label': 'TX60_2021_04_10_1_SVD_dec.npy · 110.2 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX60_2021_04_10_1_SVD_dec.npy")'},
#               {'name': 'TX60_2021_04_10_trans.npz',
#                'figshare_file_id': 54184145,
#                'category': 'retinotopy',
#                'size_bytes': 1755594,
#                'size': '1.7 MiB',
#                'size_mib': 1.674264907836914,
#                'size_gib': 0.0016350243240594864,
#                'md5': 'de474ee378baa4d10d3e880c7e3b3cfd',
#                'relative_path': 'data/retinotopy/TX60_2021_04_10_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX60_2021_04_10',
#                'label': 'TX60_2021_04_10_trans.npz · 1.7 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX60_2021_04_10_trans.npz")'}],
#     'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'VR2_2021_03_20_1',
#     'mouse': 'VR2',
#     'date': '2021-03-20',
#     'block': '1',
#     'retinotopy_id': 'VR2_2021_03_20',
#     'experiments': ('sup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 8215257677,
#     'published_size': '7.7 GiB',
#     'files': [{'name': 'Beh_sup_train1_before_learning.npy',
#                'figshare_file_id': 54183863,
#                'category': 'imaging_behavior',
#                'size_bytes': 124559852,
#                'size': '118.8 MiB',
#                'size_mib': 118.78953170776367,
#                'size_gib': 0.11600540205836296,
#                'md5': '75169b8c4c02f5ed9af3fd492e93b9bd',
#                'relative_path': 'data/beh/Beh_sup_train1_before_learning.npy',
#                'experiment': 'sup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_before_learning.npy · 118.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_before_learning.npy")'},
#               {'name': 'VR2_2021_03_20_1_neural_data.npy',
#                'figshare_file_id': 54184790,
#                'category': 'full_neural',
#                'size_bytes': 7918524289,
#                'size': '7.4 GiB',
#                'size_mib': 7551.693238258362,
#                'size_gib': 7.3747004279866815,
#                'md5': '318c8dab7b16985038650c712af82e83',
#                'relative_path': 'data/spk/VR2_2021_03_20_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'VR2_2021_03_20_1',
#                'retinotopy_id': None,
#                'label': 'VR2_2021_03_20_1_neural_data.npy · 7.4 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("VR2_2021_03_20_1_neural_data.npy")'},
#               {'name': 'VR2_2021_03_20_1_SVD_dec.npy',
#                'figshare_file_id': 54866354,
#                'category': 'reduced_neural',
#                'size_bytes': 169239266,
#                'size': '161.4 MiB',
#                'size_mib': 161.3991413116455,
#                'size_gib': 0.15761634893715382,
#                'md5': '8ecba1a1d76f4f5a231dcdff38d6e54f',
#                'relative_path': 'data/SVD_dec/VR2_2021_03_20_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'VR2_2021_03_20_1',
#                'retinotopy_id': None,
#                'label': 'VR2_2021_03_20_1_SVD_dec.npy · 161.4 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("VR2_2021_03_20_1_SVD_dec.npy")'},
#               {'name': 'VR2_2021_03_20_trans.npz',
#                'figshare_file_id': 54184211,
#                'category': 'retinotopy',
#                'size_bytes': 2934270,
#                'size': '2.8 MiB',
#                'size_mib': 2.798337936401367,
#                'size_gib': 0.00273275189101696,
#                'md5': 'f8fbb33ee2c9461011306c5072d0b06e',
#                'relative_path': 'data/retinotopy/VR2_2021_03_20_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'VR2_2021_03_20',
#                'label': 'VR2_2021_03_20_trans.npz · 2.8 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("VR2_2021_03_20_trans.npz")'}],
#     'load': {'behavior:sup_train1_before_learning': 'session.load("behavior", '
#                                                     'experiment="sup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})],
#   'sup_train1_after_learning': [Recording({'recording_id': 'TX108_2023_03_22_1',
#     'mouse': 'TX108',
#     'date': '2023-03-22',
#     'block': '1',
#     'retinotopy_id': 'TX108_2023_03_22',
#     'experiments': ('sup_train1_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 6175517868,
#     'published_size': '5.8 GiB',
#     'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#                'figshare_file_id': 54183860,
#                'category': 'imaging_behavior',
#                'size_bytes': 113352887,
#                'size': '108.1 MiB',
#                'size_mib': 108.1017370223999,
#                'size_gib': 0.1055681025609374,
#                'md5': '08c7066c45c4edfb871ff29b314ba64a',
#                'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#                'experiment': 'sup_train1_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#               {'name': 'TX108_2023_03_22_1_neural_data.npy',
#                'figshare_file_id': 54184700,
#                'category': 'full_neural',
#                'size_bytes': 5907367193,
#                'size': '5.5 GiB',
#                'size_mib': 5633.704369544983,
#                'size_gib': 5.501664423383772,
#                'md5': '4cde6c5d3f33c3a1f5c65150c722a242',
#                'relative_path': 'data/spk/TX108_2023_03_22_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_22_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_22_1_neural_data.npy · 5.5 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_22_1_neural_data.npy")'},
#               {'name': 'TX108_2023_03_22_1_SVD_dec.npy',
#                'figshare_file_id': 54866273,
#                'category': 'reduced_neural',
#                'size_bytes': 152079266,
#                'size': '145.0 MiB',
#                'size_mib': 145.03409004211426,
#                'size_gib': 0.1416348535567522,
#                'md5': '0a933f53cbe7702b89467c66ebc07b34',
#                'relative_path': 'data/SVD_dec/TX108_2023_03_22_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX108_2023_03_22_1',
#                'retinotopy_id': None,
#                'label': 'TX108_2023_03_22_1_SVD_dec.npy · 145.0 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX108_2023_03_22_1_SVD_dec.npy")'},
#               {'name': 'TX108_2023_03_22_trans.npz',
#                'figshare_file_id': 54184052,
#                'category': 'retinotopy',
#                'size_bytes': 2718522,
#                'size': '2.6 MiB',
#                'size_mib': 2.5925846099853516,
#                'size_gib': 0.00253182090818882,
#                'md5': '5083ea99f53082ef53df7fb0a1334a50',
#                'relative_path': 'data/retinotopy/TX108_2023_03_22_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX108_2023_03_22',
#                'label': 'TX108_2023_03_22_trans.npz · 2.6 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX108_2023_03_22_trans.npz")'}],
#     'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train1_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX109_2023_04_07_1',
#     'mouse': 'TX109',
#     'date': '2023-04-07',
#     'block': '1',
#     'retinotopy_id': 'TX109_2023_04_07',
#     'experiments': ('sup_train1_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 7465626308,
#     'published_size': '7.0 GiB',
#     'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#                'figshare_file_id': 54183860,
#                'category': 'imaging_behavior',
#                'size_bytes': 113352887,
#                'size': '108.1 MiB',
#                'size_mib': 108.1017370223999,
#                'size_gib': 0.1055681025609374,
#                'md5': '08c7066c45c4edfb871ff29b314ba64a',
#                'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#                'experiment': 'sup_train1_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#               {'name': 'TX109_2023_04_07_1_neural_data.npy',
#                'figshare_file_id': 54184775,
#                'category': 'full_neural',
#                'size_bytes': 7173684941,
#                'size': '6.7 GiB',
#                'size_mib': 6841.359082221985,
#                'size_gib': 6.681014728732407,
#                'md5': 'b6a44ef7ff410d8d711808afa533815c',
#                'relative_path': 'data/spk/TX109_2023_04_07_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_04_07_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_04_07_1_neural_data.npy · 6.7 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_04_07_1_neural_data.npy")'},
#               {'name': 'TX109_2023_04_07_1_SVD_dec.npy',
#                'figshare_file_id': 54866318,
#                'category': 'reduced_neural',
#                'size_bytes': 175362466,
#                'size': '167.2 MiB',
#                'size_mib': 167.23867988586426,
#                'size_gib': 0.16331902332603931,
#                'md5': '805f141dec3a536abaf0015d837ab049',
#                'relative_path': 'data/SVD_dec/TX109_2023_04_07_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX109_2023_04_07_1',
#                'retinotopy_id': None,
#                'label': 'TX109_2023_04_07_1_SVD_dec.npy · 167.2 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX109_2023_04_07_1_SVD_dec.npy")'},
#               {'name': 'TX109_2023_04_07_trans.npz',
#                'figshare_file_id': 54184091,
#                'category': 'retinotopy',
#                'size_bytes': 3226014,
#                'size': '3.1 MiB',
#                'size_mib': 3.076566696166992,
#                'size_gib': 0.0030044596642255783,
#                'md5': '2258c5a2bdd9706ba023fc14cc18a353',
#                'relative_path': 'data/retinotopy/TX109_2023_04_07_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX109_2023_04_07',
#                'label': 'TX109_2023_04_07_trans.npz · 3.1 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX109_2023_04_07_trans.npz")'}],
#     'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train1_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX60_2021_05_04_1',
#     'mouse': 'TX60',
#     'date': '2021-05-04',
#     'block': '1',
#     'retinotopy_id': 'TX60_2021_05_04',
#     'experiments': ('sup_train1_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 4268535784,
#     'published_size': '4.0 GiB',
#     'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#                'figshare_file_id': 54183860,
#                'category': 'imaging_behavior',
#                'size_bytes': 113352887,
#                'size': '108.1 MiB',
#                'size_mib': 108.1017370223999,
#                'size_gib': 0.1055681025609374,
#                'md5': '08c7066c45c4edfb871ff29b314ba64a',
#                'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#                'experiment': 'sup_train1_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#               {'name': 'TX60_2021_05_04_1_neural_data.npy',
#                'figshare_file_id': 54184628,
#                'category': 'full_neural',
#                'size_bytes': 4033200345,
#                'size': '3.8 GiB',
#                'size_mib': 3846.3595819473267,
#                'size_gib': 3.756210529245436,
#                'md5': '24fce049441942e91ae5427cb6c3544e',
#                'relative_path': 'data/spk/TX60_2021_05_04_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX60_2021_05_04_1',
#                'retinotopy_id': None,
#                'label': 'TX60_2021_05_04_1_neural_data.npy · 3.8 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX60_2021_05_04_1_neural_data.npy")'},
#               {'name': 'TX60_2021_05_04_1_SVD_dec.npy',
#                'figshare_file_id': 54866216,
#                'category': 'reduced_neural',
#                'size_bytes': 119916062,
#                'size': '114.4 MiB',
#                'size_mib': 114.36086845397949,
#                'size_gib': 0.11168053559958935,
#                'md5': 'b80f47e80503341f3993a60eb9357f32',
#                'relative_path': 'data/SVD_dec/TX60_2021_05_04_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX60_2021_05_04_1',
#                'retinotopy_id': None,
#                'label': 'TX60_2021_05_04_1_SVD_dec.npy · 114.4 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX60_2021_05_04_1_SVD_dec.npy")'},
#               {'name': 'TX60_2021_05_04_trans.npz',
#                'figshare_file_id': 54184148,
#                'category': 'retinotopy',
#                'size_bytes': 2066490,
#                'size': '2.0 MiB',
#                'size_mib': 1.9707584381103516,
#                'size_gib': 0.0019245687872171402,
#                'md5': '50d07ddbd9cdd8e2f2fd44da2783ab43',
#                'relative_path': 'data/retinotopy/TX60_2021_05_04_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX60_2021_05_04',
#                'label': 'TX60_2021_05_04_trans.npz · 2.0 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX60_2021_05_04_trans.npz")'}],
#     'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train1_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'VR2_2021_04_06_1',
#     'mouse': 'VR2',
#     'date': '2021-04-06',
#     'block': '1',
#     'retinotopy_id': 'VR2_2021_04_06',
#     'experiments': ('sup_train1_after_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 5306786912,
#     'published_size': '4.9 GiB',
#     'files': [{'name': 'Beh_sup_train1_after_learning.npy',
#                'figshare_file_id': 54183860,
#                'category': 'imaging_behavior',
#                'size_bytes': 113352887,
#                'size': '108.1 MiB',
#                'size_mib': 108.1017370223999,
#                'size_gib': 0.1055681025609374,
#                'md5': '08c7066c45c4edfb871ff29b314ba64a',
#                'relative_path': 'data/beh/Beh_sup_train1_after_learning.npy',
#                'experiment': 'sup_train1_after_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_sup_train1_after_learning.npy · 108.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_sup_train1_after_learning.npy")'},
#               {'name': 'VR2_2021_04_06_1_neural_data.npy',
#                'figshare_file_id': 54184673,
#                'category': 'full_neural',
#                'size_bytes': 5048742233,
#                'size': '4.7 GiB',
#                'size_mib': 4814.855797767639,
#                'size_gib': 4.70200761500746,
#                'md5': 'b367e8cb78da35fdf59ab4ed87c4eb68',
#                'relative_path': 'data/spk/VR2_2021_04_06_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'VR2_2021_04_06_1',
#                'retinotopy_id': None,
#                'label': 'VR2_2021_04_06_1_neural_data.npy · 4.7 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("VR2_2021_04_06_1_neural_data.npy")'},
#               {'name': 'VR2_2021_04_06_1_SVD_dec.npy',
#                'figshare_file_id': 54866333,
#                'category': 'reduced_neural',
#                'size_bytes': 142132066,
#                'size': '135.5 MiB',
#                'size_mib': 135.547700881958,
#                'size_gib': 0.13237080164253712,
#                'md5': '9a9554cc07ab5ad34b750ca7ea0e6920',
#                'relative_path': 'data/SVD_dec/VR2_2021_04_06_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'VR2_2021_04_06_1',
#                'retinotopy_id': None,
#                'label': 'VR2_2021_04_06_1_SVD_dec.npy · 135.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("VR2_2021_04_06_1_SVD_dec.npy")'},
#               {'name': 'VR2_2021_04_06_trans.npz',
#                'figshare_file_id': 54184214,
#                'category': 'retinotopy',
#                'size_bytes': 2559726,
#                'size': '2.4 MiB',
#                'size_mib': 2.4411449432373047,
#                'size_gib': 0.0023839306086301804,
#                'md5': '18d654e4e560854540c75c8b3e2ed235',
#                'relative_path': 'data/retinotopy/VR2_2021_04_06_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'VR2_2021_04_06',
#                'label': 'VR2_2021_04_06_trans.npz · 2.4 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("VR2_2021_04_06_trans.npz")'}],
#     'load': {'behavior:sup_train1_after_learning': 'session.load("behavior", '
#                                                    'experiment="sup_train1_after_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})]},
#  'unsupervised': {'unsup_train1_before_learning': [Recording({'recording_id': 'DR10_2022_07_12_1',
#     'mouse': 'DR10',
#     'date': '2022-07-12',
#     'block': '1',
#     'retinotopy_id': 'DR10_2022_07_12',
#     'experiments': ('unsup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 7838884877,
#     'published_size': '7.3 GiB',
#     'files': [{'name': 'Beh_unsup_train1_before_learning.npy',
#                'figshare_file_id': 54183914,
#                'category': 'imaging_behavior',
#                'size_bytes': 308224980,
#                'size': '293.9 MiB',
#                'size_mib': 293.9462471008301,
#                'size_gib': 0.2870568819344044,
#                'md5': 'a24dd14d900228ca37f6c9cdbe49e762',
#                'relative_path': 'data/beh/Beh_unsup_train1_before_learning.npy',
#                'experiment': 'unsup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_unsup_train1_before_learning.npy · 293.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_unsup_train1_before_learning.npy")'},
#               {'name': 'DR10_2022_07_12_1_neural_data.npy',
#                'figshare_file_id': 54184778,
#                'category': 'full_neural',
#                'size_bytes': 7384433945,
#                'size': '6.9 GiB',
#                'size_mib': 7042.344994544983,
#                'size_gib': 6.877290033735335,
#                'md5': 'f632e105fccc0b629f2be62aced34347',
#                'relative_path': 'data/spk/DR10_2022_07_12_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'DR10_2022_07_12_1',
#                'retinotopy_id': None,
#                'label': 'DR10_2022_07_12_1_neural_data.npy · 6.9 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("DR10_2022_07_12_1_neural_data.npy")'},
#               {'name': 'DR10_2022_07_12_1_SVD_dec.npy',
#                'figshare_file_id': 54866219,
#                'category': 'reduced_neural',
#                'size_bytes': 143895262,
#                'size': '137.2 MiB',
#                'size_mib': 137.22921562194824,
#                'size_gib': 0.13401290588080883,
#                'md5': '461787c8e0ac2e8700f5f5b4669d2418',
#                'relative_path': 'data/SVD_dec/DR10_2022_07_12_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'DR10_2022_07_12_1',
#                'retinotopy_id': None,
#                'label': 'DR10_2022_07_12_1_SVD_dec.npy · 137.2 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("DR10_2022_07_12_1_SVD_dec.npy")'},
#               {'name': 'DR10_2022_07_12_trans.npz',
#                'figshare_file_id': 54183980,
#                'category': 'retinotopy',
#                'size_bytes': 2330690,
#                'size': '2.2 MiB',
#                'size_mib': 2.222719192504883,
#                'size_gib': 0.0021706242114305496,
#                'md5': '44890105820924b884693bdbd206e4b7',
#                'relative_path': 'data/retinotopy/DR10_2022_07_12_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'DR10_2022_07_12',
#                'label': 'DR10_2022_07_12_trans.npz · 2.2 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("DR10_2022_07_12_trans.npz")'}],
#     'load': {'behavior:unsup_train1_before_learning': 'session.load("behavior", '
#                                                       'experiment="unsup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'DR15_2022_10_09_1',
#     'mouse': 'DR15',
#     'date': '2022-10-09',
#     'block': '1',
#     'retinotopy_id': 'DR15_2022_10_09',
#     'experiments': ('unsup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 6996811285,
#     'published_size': '6.5 GiB',
#     'files': [{'name': 'Beh_unsup_train1_before_learning.npy',
#                'figshare_file_id': 54183914,
#                'category': 'imaging_behavior',
#                'size_bytes': 308224980,
#                'size': '293.9 MiB',
#                'size_mib': 293.9462471008301,
#                'size_gib': 0.2870568819344044,
#                'md5': 'a24dd14d900228ca37f6c9cdbe49e762',
#                'relative_path': 'data/beh/Beh_unsup_train1_before_learning.npy',
#                'experiment': 'unsup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_unsup_train1_before_learning.npy · 293.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_unsup_train1_before_learning.npy")'},
#               {'name': 'DR15_2022_10_09_1_neural_data.npy',
#                'figshare_file_id': 54184739,
#                'category': 'full_neural',
#                'size_bytes': 6550155473,
#                'size': '6.1 GiB',
#                'size_mib': 6246.715043067932,
#                'size_gib': 6.1003076592460275,
#                'md5': 'baeb8a2bde277cf328b97af4f4ce7fe8',
#                'relative_path': 'data/spk/DR15_2022_10_09_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'DR15_2022_10_09_1',
#                'retinotopy_id': None,
#                'label': 'DR15_2022_10_09_1_neural_data.npy · 6.1 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("DR15_2022_10_09_1_neural_data.npy")'},
#               {'name': 'DR15_2022_10_09_1_SVD_dec.npy',
#                'figshare_file_id': 54866213,
#                'category': 'reduced_neural',
#                'size_bytes': 136199262,
#                'size': '129.9 MiB',
#                'size_mib': 129.88973808288574,
#                'size_gib': 0.1268454473465681,
#                'md5': '18c3b24e10b0439bfd0eb03547ed20e0',
#                'relative_path': 'data/SVD_dec/DR15_2022_10_09_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'DR15_2022_10_09_1',
#                'retinotopy_id': None,
#                'label': 'DR15_2022_10_09_1_SVD_dec.npy · 129.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("DR15_2022_10_09_1_SVD_dec.npy")'},
#               {'name': 'DR15_2022_10_09_trans.npz',
#                'figshare_file_id': 54184007,
#                'category': 'retinotopy',
#                'size_bytes': 2231570,
#                'size': '2.1 MiB',
#                'size_mib': 2.1281909942626953,
#                'size_gib': 0.0020783115178346634,
#                'md5': 'a6dd81e4397f1b3f4d8e6ae4a74791c4',
#                'relative_path': 'data/retinotopy/DR15_2022_10_09_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'DR15_2022_10_09',
#                'label': 'DR15_2022_10_09_trans.npz · 2.1 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("DR15_2022_10_09_trans.npz")'}],
#     'load': {'behavior:unsup_train1_before_learning': 'session.load("behavior", '
#                                                       'experiment="unsup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX104_2022_10_12_1',
#     'mouse': 'TX104',
#     'date': '2022-10-12',
#     'block': '1',
#     'retinotopy_id': 'TX104_2022_10_12',
#     'experiments': ('unsup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 3806663181,
#     'published_size': '3.5 GiB',
#     'files': [{'name': 'Beh_unsup_train1_before_learning.npy',
#                'figshare_file_id': 54183914,
#                'category': 'imaging_behavior',
#                'size_bytes': 308224980,
#                'size': '293.9 MiB',
#                'size_mib': 293.9462471008301,
#                'size_gib': 0.2870568819344044,
#                'md5': 'a24dd14d900228ca37f6c9cdbe49e762',
#                'relative_path': 'data/beh/Beh_unsup_train1_before_learning.npy',
#                'experiment': 'unsup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_unsup_train1_before_learning.npy · 293.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_unsup_train1_before_learning.npy")'},
#               {'name': 'TX104_2022_10_12_1_neural_data.npy',
#                'figshare_file_id': 54184580,
#                'category': 'full_neural',
#                'size_bytes': 3395557449,
#                'size': '3.2 GiB',
#                'size_mib': 3238.255928993225,
#                'size_gib': 3.1623593056574464,
#                'md5': '08dfbcfc2a041892affd194441fcdda4',
#                'relative_path': 'data/spk/TX104_2022_10_12_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX104_2022_10_12_1',
#                'retinotopy_id': None,
#                'label': 'TX104_2022_10_12_1_neural_data.npy · 3.2 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX104_2022_10_12_1_neural_data.npy")'},
#               {'name': 'TX104_2022_10_12_1_SVD_dec.npy',
#                'figshare_file_id': 54866123,
#                'category': 'reduced_neural',
#                'size_bytes': 101125662,
#                'size': '96.4 MiB',
#                'size_mib': 96.44094657897949,
#                'size_gib': 0.09418061189353466,
#                'md5': '3f3dcd3ada0097c0b08caf1e04eb2039',
#                'relative_path': 'data/SVD_dec/TX104_2022_10_12_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX104_2022_10_12_1',
#                'retinotopy_id': None,
#                'label': 'TX104_2022_10_12_1_SVD_dec.npy · 96.4 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX104_2022_10_12_1_SVD_dec.npy")'},
#               {'name': 'TX104_2022_10_12_trans.npz',
#                'figshare_file_id': 54184004,
#                'category': 'retinotopy',
#                'size_bytes': 1755090,
#                'size': '1.7 MiB',
#                'size_mib': 1.6737842559814453,
#                'size_gib': 0.0016345549374818802,
#                'md5': '65aa9b110aa36bf274a8b670d68d73db',
#                'relative_path': 'data/retinotopy/TX104_2022_10_12_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX104_2022_10_12',
#                'label': 'TX104_2022_10_12_trans.npz · 1.7 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX104_2022_10_12_trans.npz")'}],
#     'load': {'behavior:unsup_train1_before_learning': 'session.load("behavior", '
#                                                       'experiment="unsup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX105_2022_10_08_2',
#     'mouse': 'TX105',
#     'date': '2022-10-08',
#     'block': '2',
#     'retinotopy_id': 'TX105_2022_10_08',
#     'experiments': ('unsup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 6989373445,
#     'published_size': '6.5 GiB',
#     'files': [{'name': 'Beh_unsup_train1_before_learning.npy',
#                'figshare_file_id': 54183914,
#                'category': 'imaging_behavior',
#                'size_bytes': 308224980,
#                'size': '293.9 MiB',
#                'size_mib': 293.9462471008301,
#                'size_gib': 0.2870568819344044,
#                'md5': 'a24dd14d900228ca37f6c9cdbe49e762',
#                'relative_path': 'data/beh/Beh_unsup_train1_before_learning.npy',
#                'experiment': 'unsup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_unsup_train1_before_learning.npy · 293.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_unsup_train1_before_learning.npy")'},
#               {'name': 'TX105_2022_10_08_2_neural_data.npy',
#                'figshare_file_id': 54184742,
#                'category': 'full_neural',
#                'size_bytes': 6540093833,
#                'size': '6.1 GiB',
#                'size_mib': 6237.119515419006,
#                'size_gib': 6.090937026776373,
#                'md5': 'a2ab5df90678f6716231ecd09fd22ac4',
#                'relative_path': 'data/spk/TX105_2022_10_08_2_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX105_2022_10_08_2',
#                'retinotopy_id': None,
#                'label': 'TX105_2022_10_08_2_neural_data.npy · 6.1 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX105_2022_10_08_2_neural_data.npy")'},
#               {'name': 'TX105_2022_10_08_2_SVD_dec.npy',
#                'figshare_file_id': 54866237,
#                'category': 'reduced_neural',
#                'size_bytes': 138695262,
#                'size': '132.3 MiB',
#                'size_mib': 132.27010917663574,
#                'size_gib': 0.12917002849280834,
#                'md5': '436bb45d119981e6b88b246d2be3a2cd',
#                'relative_path': 'data/SVD_dec/TX105_2022_10_08_2_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX105_2022_10_08_2',
#                'retinotopy_id': None,
#                'label': 'TX105_2022_10_08_2_SVD_dec.npy · 132.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX105_2022_10_08_2_SVD_dec.npy")'},
#               {'name': 'TX105_2022_10_08_trans.npz',
#                'figshare_file_id': 54184028,
#                'category': 'retinotopy',
#                'size_bytes': 2359370,
#                'size': '2.3 MiB',
#                'size_mib': 2.250070571899414,
#                'size_gib': 0.0021973345428705215,
#                'md5': '925cbea0c97f621a7a9e04c2f652801a',
#                'relative_path': 'data/retinotopy/TX105_2022_10_08_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX105_2022_10_08',
#                'label': 'TX105_2022_10_08_trans.npz · 2.3 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX105_2022_10_08_trans.npz")'}],
#     'load': {'behavior:unsup_train1_before_learning': 'session.load("behavior", '
#                                                       'experiment="unsup_train1_before_learning")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX119_2023_12_14_1',
#     'mouse': 'TX119',
#     'date': '2023-12-14',
#     'block': '1',
#     'retinotopy_id': 'TX119_2023_12_14',
#     'experiments': ('unsup_train1_before_learning',),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 4,
#     'published_bytes': 2339788165,
#     'published_size': '2.2 GiB',
#     'files': [{'name': 'Beh_unsup_train1_before_learning.npy',
#                'figshare_file_id': 54183914,
#                'category': 'imaging_behavior',
#                'size_bytes': 308224980,
#                'size': '293.9 MiB',
#                'size_mib': 293.9462471008301,
#                'size_gib': 0.2870568819344044,
#                'md5': 'a24dd14d900228ca37f6c9cdbe49e762',
#                'relative_path': 'data/beh/Beh_unsup_train1_before_learning.npy',
#                'experiment': 'unsup_train1_before_learning',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_unsup_train1_before_learning.npy · 293.9 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_unsup_train1_before_learning.npy")'},
#               {'name': 'TX119_2023_12_14_1_neural_data.npy',
#                'figshare_file_id': 54184496,
#                'category': 'full_neural',
#                'size_bytes': 1955049689,
#                'size': '1.8 GiB',
# ...
#                'size_mib': 1.2128047943115234,
#                'size_gib': 0.001184379681944847,
#                'md5': 'e8933d9414b6cf37a1040ebd0a93786f',
#                'relative_path': 'data/retinotopy/LZ16_2024_06_01_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'LZ16_2024_06_01',
#                'label': 'LZ16_2024_06_01_trans.npz · 1.2 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("LZ16_2024_06_01_trans.npz")'}],
#     'load': {'behavior:test1_after_grating': 'session.load("behavior", '
#                                              'experiment="test1_after_grating")',
#              'behavior:test2_after_grating': 'session.load("behavior", '
#                                              'experiment="test2_after_grating")',
#              'behavior:train1_after_grating': 'session.load("behavior", '
#                                               'experiment="train1_after_grating")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX139_2024_05_31_1',
#     'mouse': 'TX139',
#     'date': '2024-05-31',
#     'block': '1',
#     'retinotopy_id': 'TX139_2024_05_31',
#     'experiments': ('test1_after_grating', 'test2_after_grating', 'train1_after_grating'),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 6,
#     'published_bytes': 4422601110,
#     'published_size': '4.1 GiB',
#     'files': [{'name': 'Beh_test1_after_grating.npy',
#                'figshare_file_id': 54183890,
#                'category': 'imaging_behavior',
#                'size_bytes': 201376774,
#                'size': '192.0 MiB',
#                'size_mib': 192.0478572845459,
#                'size_gib': 0.18754673562943935,
#                'md5': 'fab95e365509b57b94cd485440fe55f2',
#                'relative_path': 'data/beh/Beh_test1_after_grating.npy',
#                'experiment': 'test1_after_grating',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_test1_after_grating.npy · 192.0 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_test1_after_grating.npy")'},
#               {'name': 'Beh_test2_after_grating.npy',
#                'figshare_file_id': 54183896,
#                'category': 'imaging_behavior',
#                'size_bytes': 201376772,
#                'size': '192.0 MiB',
#                'size_mib': 192.04785537719727,
#                'size_gib': 0.1875467337667942,
#                'md5': 'a079a211852cd4bca56033feeb54c3a3',
#                'relative_path': 'data/beh/Beh_test2_after_grating.npy',
#                'experiment': 'test2_after_grating',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_test2_after_grating.npy · 192.0 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_test2_after_grating.npy")'},
#               {'name': 'Beh_train1_after_grating.npy',
#                'figshare_file_id': 54183893,
#                'category': 'imaging_behavior',
#                'size_bytes': 201145291,
#                'size': '191.8 MiB',
#                'size_mib': 191.82709789276123,
#                'size_gib': 0.18733115028589964,
#                'md5': '9184dddef39aaef10c3259c1e0748a33',
#                'relative_path': 'data/beh/Beh_train1_after_grating.npy',
#                'experiment': 'train1_after_grating',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_train1_after_grating.npy · 191.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_train1_after_grating.npy")'},
#               {'name': 'TX139_2024_05_31_1_neural_data.npy',
#                'figshare_file_id': 54184601,
#                'category': 'full_neural',
#                'size_bytes': 3719124577,
#                'size': '3.5 GiB',
#                'size_mib': 3546.8335886001587,
#                'size_gib': 3.4637046763673425,
#                'md5': 'b3be1c7cd09a8a9a0a147c0982ac5113',
#                'relative_path': 'data/spk/TX139_2024_05_31_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX139_2024_05_31_1',
#                'retinotopy_id': None,
#                'label': 'TX139_2024_05_31_1_neural_data.npy · 3.5 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX139_2024_05_31_1_neural_data.npy")'},
#               {'name': 'TX139_2024_05_31_1_SVD_dec.npy',
#                'figshare_file_id': 54866141,
#                'category': 'reduced_neural',
#                'size_bytes': 98333662,
#                'size': '93.8 MiB',
#                'size_mib': 93.77828788757324,
#                'size_gib': 0.09158035926520824,
#                'md5': '3ca56bfcb8cdb33eea098bfa67a90009',
#                'relative_path': 'data/SVD_dec/TX139_2024_05_31_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX139_2024_05_31_1',
#                'retinotopy_id': None,
#                'label': 'TX139_2024_05_31_1_SVD_dec.npy · 93.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX139_2024_05_31_1_SVD_dec.npy")'},
#               {'name': 'TX139_2024_05_31_trans.npz',
#                'figshare_file_id': 54184139,
#                'category': 'retinotopy',
#                'size_bytes': 1244034,
#                'size': '1.2 MiB',
#                'size_mib': 1.1864032745361328,
#                'size_gib': 0.0011585969477891922,
#                'md5': '00a2a0b8302cf6491220fd2283e5ca2b',
#                'relative_path': 'data/retinotopy/TX139_2024_05_31_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX139_2024_05_31',
#                'label': 'TX139_2024_05_31_trans.npz · 1.2 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX139_2024_05_31_trans.npz")'}],
#     'load': {'behavior:test1_after_grating': 'session.load("behavior", '
#                                              'experiment="test1_after_grating")',
#              'behavior:test2_after_grating': 'session.load("behavior", '
#                                              'experiment="test2_after_grating")',
#              'behavior:train1_after_grating': 'session.load("behavior", '
#                                               'experiment="train1_after_grating")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})]},
#  'naive': {'naive_test1': [Recording({'recording_id': 'TX124_2023_12_23_1',
#     'mouse': 'TX124',
#     'date': '2023-12-23',
#     'block': '1',
#     'retinotopy_id': 'TX124_2023_12_23',
#     'experiments': ('naive_test1', 'naive_test2'),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 5,
#     'published_bytes': 2701139328,
#     'published_size': '2.5 GiB',
#     'files': [{'name': 'Beh_naive_test1.npy',
#                'figshare_file_id': 54183923,
#                'category': 'imaging_behavior',
#                'size_bytes': 432561586,
#                'size': '412.5 MiB',
#                'size_mib': 412.5228748321533,
#                'size_gib': 0.4028543699532747,
#                'md5': 'c582b1937ee1917dce1512036b346ba3',
#                'relative_path': 'data/beh/Beh_naive_test1.npy',
#                'experiment': 'naive_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test1.npy · 412.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test1.npy")'},
#               {'name': 'Beh_naive_test2.npy',
#                'figshare_file_id': 54183908,
#                'category': 'imaging_behavior',
#                'size_bytes': 286584765,
#                'size': '273.3 MiB',
#                'size_mib': 273.3085298538208,
#                'size_gib': 0.2669028611853719,
#                'md5': 'b622db42667fb01b433eef841dd58599',
#                'relative_path': 'data/beh/Beh_naive_test2.npy',
#                'experiment': 'naive_test2',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test2.npy · 273.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test2.npy")'},
#               {'name': 'TX124_2023_12_23_1_neural_data.npy',
#                'figshare_file_id': 54184490,
#                'category': 'full_neural',
#                'size_bytes': 1910749885,
#                'size': '1.8 GiB',
#                'size_mib': 1822.2330904006958,
#                'size_gib': 1.7795245023444295,
#                'md5': 'ff5ffca5dc8b1c41f3bd1c8cb4e4f153',
#                'relative_path': 'data/spk/TX124_2023_12_23_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_23_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_23_1_neural_data.npy · 1.8 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_23_1_neural_data.npy")'},
#               {'name': 'TX124_2023_12_23_1_SVD_dec.npy',
#                'figshare_file_id': 54866066,
#                'category': 'reduced_neural',
#                'size_bytes': 70364062,
#                'size': '67.1 MiB',
#                'size_mib': 67.10439872741699,
#                'size_gib': 0.06553163938224316,
#                'md5': '8413a4248c40f94cfff8e45b84cb6b06',
#                'relative_path': 'data/SVD_dec/TX124_2023_12_23_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX124_2023_12_23_1',
#                'retinotopy_id': None,
#                'label': 'TX124_2023_12_23_1_SVD_dec.npy · 67.1 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX124_2023_12_23_1_SVD_dec.npy")'},
#               {'name': 'TX124_2023_12_23_trans.npz',
#                'figshare_file_id': 54184127,
#                'category': 'retinotopy',
#                'size_bytes': 879030,
#                'size': '858.4 KiB',
#                'size_mib': 0.8383083343505859,
#                'size_gib': 0.0008186604827642441,
#                'md5': 'a46a0315fd4ebff958b63cbc0dd3f3d0',
#                'relative_path': 'data/retinotopy/TX124_2023_12_23_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX124_2023_12_23',
#                'label': 'TX124_2023_12_23_trans.npz · 858.4 KiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX124_2023_12_23_trans.npz")'}],
#     'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#              'behavior:naive_test2': 'session.load("behavior", experiment="naive_test2")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'}),
#    Recording({'recording_id': 'TX140_2024_05_31_1',
#     'mouse': 'TX140',
#     'date': '2024-05-31',
#     'block': '1',
#     'retinotopy_id': 'TX140_2024_05_31',
#     'experiments': ('naive_test1', 'naive_test2'),
#     'layers': ('behavior', 'reduced_neural', 'full_neural', 'retinotopy'),
#     'published_file_count': 5,
#     'published_bytes': 5822824808,
#     'published_size': '5.4 GiB',
#     'files': [{'name': 'Beh_naive_test1.npy',
#                'figshare_file_id': 54183923,
#                'category': 'imaging_behavior',
#                'size_bytes': 432561586,
#                'size': '412.5 MiB',
#                'size_mib': 412.5228748321533,
#                'size_gib': 0.4028543699532747,
#                'md5': 'c582b1937ee1917dce1512036b346ba3',
#                'relative_path': 'data/beh/Beh_naive_test1.npy',
#                'experiment': 'naive_test1',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test1.npy · 412.5 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test1.npy")'},
#               {'name': 'Beh_naive_test2.npy',
#                'figshare_file_id': 54183908,
#                'category': 'imaging_behavior',
#                'size_bytes': 286584765,
#                'size': '273.3 MiB',
#                'size_mib': 273.3085298538208,
#                'size_gib': 0.2669028611853719,
#                'md5': 'b622db42667fb01b433eef841dd58599',
#                'relative_path': 'data/beh/Beh_naive_test2.npy',
#                'experiment': 'naive_test2',
#                'recording_id': None,
#                'retinotopy_id': None,
#                'label': 'Beh_naive_test2.npy · 273.3 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("Beh_naive_test2.npy")'},
#               {'name': 'TX140_2024_05_31_1_neural_data.npy',
#                'figshare_file_id': 54184667,
#                'category': 'full_neural',
#                'size_bytes': 4982581157,
#                'size': '4.6 GiB',
#                'size_mib': 4751.759678840637,
#                'size_gib': 4.64039031136781,
#                'md5': '267d3e0660b3d6306ecb8846cfe15aa7',
#                'relative_path': 'data/spk/TX140_2024_05_31_1_neural_data.npy',
#                'experiment': None,
#                'recording_id': 'TX140_2024_05_31_1',
#                'retinotopy_id': None,
#                'label': 'TX140_2024_05_31_1_neural_data.npy · 4.6 GiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX140_2024_05_31_1_neural_data.npy")'},
#               {'name': 'TX140_2024_05_31_1_SVD_dec.npy',
#                'figshare_file_id': 54866201,
#                'category': 'reduced_neural',
#                'size_bytes': 119320862,
#                'size': '113.8 MiB',
#                'size_mib': 113.79324150085449,
#                'size_gib': 0.11112621240317822,
#                'md5': 'beef506a82de5ba82d89b9a93a350783',
#                'relative_path': 'data/SVD_dec/TX140_2024_05_31_1_SVD_dec.npy',
#                'experiment': None,
#                'recording_id': 'TX140_2024_05_31_1',
#                'retinotopy_id': None,
#                'label': 'TX140_2024_05_31_1_SVD_dec.npy · 113.8 MiB',
#                'suffix': '.npy',
#                'load': 'data.load("TX140_2024_05_31_1_SVD_dec.npy")'},
#               {'name': 'TX140_2024_05_31_trans.npz',
#                'figshare_file_id': 54184142,
#                'category': 'retinotopy',
#                'size_bytes': 1776438,
#                'size': '1.7 MiB',
#                'size_mib': 1.694143295288086,
#                'size_gib': 0.0016544368118047714,
#                'md5': 'b36b8991596a5aab8de0ae3e6afeda72',
#                'relative_path': 'data/retinotopy/TX140_2024_05_31_trans.npz',
#                'experiment': None,
#                'recording_id': None,
#                'retinotopy_id': 'TX140_2024_05_31',
#                'label': 'TX140_2024_05_31_trans.npz · 1.7 MiB',
#                'suffix': '.npz',
#                'load': 'data.load("TX140_2024_05_31_trans.npz")'}],
#     'load': {'behavior:naive_test1': 'session.load("behavior", experiment="naive_test1")',
#              'behavior:naive_test2': 'session.load("behavior", experiment="naive_test2")',
#              'reduced_neural': 'session.load("reduced_neural")',
#              'full_neural': 'session.load("full_neural")',
#              'retinotopy': 'session.load("retinotopy")'},
#     'dataset': {'type': 'Dataset', 'connected': True, 'access': 'session.dataset'},
#     'availability': 'mounted'})]}}

# %%
{ category: recording.keys() for (category, recording) in train1_recordings.items() }
# Out:
# {'supervised': dict_keys(['sup_train1_before_learning', 'sup_train1_after_learning']),
#  'unsupervised': dict_keys(['unsup_train1_before_learning', 'unsup_train1_after_learning']),
#  'grating': dict_keys(['train1_before_grating', 'train1_after_grating']),
#  'naive': dict_keys(['naive_test1'])}

# %%
files(train1_recordings['naive']['naive_test1'])
# Out:
# [['Beh_naive_test1.npy',
#   'Beh_naive_test2.npy',
#   'TX124_2023_12_23_1_SVD_dec.npy',
#   'TX124_2023_12_23_1_neural_data.npy',
#   'TX124_2023_12_23_trans.npz'],
#  ['Beh_naive_test1.npy',
#   'Beh_naive_test2.npy',
#   'TX140_2024_05_31_1_SVD_dec.npy',
#   'TX140_2024_05_31_1_neural_data.npy',
#   'TX140_2024_05_31_trans.npz']]

# %%
file_map = {
    category: {
        label: files(recordings)
        for (label, recordings) in recording_map.items()
    }
    for (category, recording_map) in train1_recordings.items()
}
file_map
# Out:
# {'supervised': {'sup_train1_before_learning': [['Beh_sup_train1_before_learning.npy',
#     'TX108_2023_03_13_1_SVD_dec.npy',
#     'TX108_2023_03_13_1_neural_data.npy',
#     'TX108_2023_03_13_trans.npz'],
#    ['Beh_sup_train1_before_learning.npy',
#     'TX109_2023_03_27_1_SVD_dec.npy',
#     'TX109_2023_03_27_1_neural_data.npy',
#     'TX109_2023_03_27_trans.npz'],
#    ['Beh_sup_train1_before_learning.npy',
#     'TX60_2021_04_10_1_SVD_dec.npy',
#     'TX60_2021_04_10_1_neural_data.npy',
#     'TX60_2021_04_10_trans.npz'],
#    ['Beh_sup_train1_before_learning.npy',
#     'VR2_2021_03_20_1_SVD_dec.npy',
#     'VR2_2021_03_20_1_neural_data.npy',
#     'VR2_2021_03_20_trans.npz']],
#   'sup_train1_after_learning': [['Beh_sup_train1_after_learning.npy',
#     'TX108_2023_03_22_1_SVD_dec.npy',
#     'TX108_2023_03_22_1_neural_data.npy',
#     'TX108_2023_03_22_trans.npz'],
#    ['Beh_sup_train1_after_learning.npy',
#     'TX109_2023_04_07_1_SVD_dec.npy',
#     'TX109_2023_04_07_1_neural_data.npy',
#     'TX109_2023_04_07_trans.npz'],
#    ['Beh_sup_train1_after_learning.npy',
#     'TX60_2021_05_04_1_SVD_dec.npy',
#     'TX60_2021_05_04_1_neural_data.npy',
#     'TX60_2021_05_04_trans.npz'],
#    ['Beh_sup_train1_after_learning.npy',
#     'VR2_2021_04_06_1_SVD_dec.npy',
#     'VR2_2021_04_06_1_neural_data.npy',
#     'VR2_2021_04_06_trans.npz']]},
#  'unsupervised': {'unsup_train1_before_learning': [['Beh_unsup_train1_before_learning.npy',
#     'DR10_2022_07_12_1_SVD_dec.npy',
#     'DR10_2022_07_12_1_neural_data.npy',
#     'DR10_2022_07_12_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'DR15_2022_10_09_1_SVD_dec.npy',
#     'DR15_2022_10_09_1_neural_data.npy',
#     'DR15_2022_10_09_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX104_2022_10_12_1_SVD_dec.npy',
#     'TX104_2022_10_12_1_neural_data.npy',
#     'TX104_2022_10_12_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX105_2022_10_08_2_SVD_dec.npy',
#     'TX105_2022_10_08_2_neural_data.npy',
#     'TX105_2022_10_08_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX119_2023_12_14_1_SVD_dec.npy',
#     'TX119_2023_12_14_1_neural_data.npy',
#     'TX119_2023_12_14_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX123_2023_12_21_1_SVD_dec.npy',
#     'TX123_2023_12_21_1_neural_data.npy',
#     'TX123_2023_12_21_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX83_2022_08_17_1_SVD_dec.npy',
#     'TX83_2022_08_17_1_neural_data.npy',
#     'TX83_2022_08_17_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX85_2022_06_14_1_SVD_dec.npy',
#     'TX85_2022_06_14_1_neural_data.npy',
#     'TX85_2022_06_14_trans.npz'],
#    ['Beh_unsup_train1_before_learning.npy',
#     'TX88_2022_06_13_2_SVD_dec.npy',
#     'TX88_2022_06_13_2_neural_data.npy',
#     'TX88_2022_06_13_trans.npz']],
#   'unsup_train1_after_learning': [['Beh_unsup_train1_after_learning.npy',
#     'DR10_2022_07_19_1_SVD_dec.npy',
#     'DR10_2022_07_19_1_neural_data.npy',
#     'DR10_2022_07_19_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'DR15_2022_10_19_1_SVD_dec.npy',
#     'DR15_2022_10_19_1_neural_data.npy',
#     'DR15_2022_10_19_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX104_2022_10_20_1_SVD_dec.npy',
#     'TX104_2022_10_20_1_neural_data.npy',
#     'TX104_2022_10_20_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX105_2022_10_19_2_SVD_dec.npy',
#     'TX105_2022_10_19_2_neural_data.npy',
#     'TX105_2022_10_19_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX119_2023_12_23_1_SVD_dec.npy',
#     'TX119_2023_12_23_1_neural_data.npy',
#     'TX119_2023_12_23_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX123_2024_01_02_1_SVD_dec.npy',
#     'TX123_2024_01_02_1_neural_data.npy',
#     'TX123_2024_01_02_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX83_2022_08_29_1_SVD_dec.npy',
#     'TX83_2022_08_29_1_neural_data.npy',
#     'TX83_2022_08_29_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX85_2022_06_17_1_SVD_dec.npy',
#     'TX85_2022_06_17_1_neural_data.npy',
#     'TX85_2022_06_17_trans.npz'],
#    ['Beh_unsup_train1_after_learning.npy',
#     'TX88_2022_06_17_2_SVD_dec.npy',
#     'TX88_2022_06_17_2_neural_data.npy',
#     'TX88_2022_06_17_trans.npz']]},
#  'grating': {'train1_before_grating': [['Beh_naive_test1.npy',
#     'Beh_naive_test2.npy',
#     'Beh_test1_before_grating.npy',
#     'Beh_test2_before_grating.npy',
#     'Beh_train1_before_grating.npy',
#     'LZ13_2024_05_15_1_SVD_dec.npy',
#     'LZ13_2024_05_15_1_neural_data.npy',
#     'LZ13_2024_05_15_trans.npz'],
#    ['Beh_naive_test1.npy',
#     'Beh_test1_before_grating.npy',
#     'Beh_test2_before_grating.npy',
#     'Beh_train1_before_grating.npy',
#     'LZ13_2024_05_16_2_SVD_dec.npy',
#     'LZ13_2024_05_16_2_neural_data.npy',
#     'LZ13_2024_05_16_trans.npz'],
#    ['Beh_naive_test1.npy',
#     'Beh_naive_test2.npy',
#     'Beh_test1_before_grating.npy',
#     'Beh_test2_before_grating.npy',
#     'Beh_train1_before_grating.npy',
#     'LZ16_2024_05_18_2_SVD_dec.npy',
#     'LZ16_2024_05_18_2_neural_data.npy',
#     'LZ16_2024_05_18_trans.npz'],
#    ['Beh_naive_test1.npy',
#     'Beh_test1_before_grating.npy',
#     'Beh_test2_before_grating.npy',
#     'Beh_train1_before_grating.npy',
#     'LZ16_2024_05_19_1_SVD_dec.npy',
#     'LZ16_2024_05_19_1_neural_data.npy',
#     'LZ16_2024_05_19_trans.npz'],
#    ['Beh_naive_test1.npy',
#     'Beh_naive_test2.npy',
#     'Beh_test1_before_grating.npy',
#     'Beh_test2_before_grating.npy',
#     'Beh_train1_before_grating.npy',
#     'TX139_2024_05_18_1_SVD_dec.npy',
#     'TX139_2024_05_18_1_neural_data.npy',
#     'TX139_2024_05_18_trans.npz']],
#   'train1_after_grating': [['Beh_test1_after_grating.npy',
#     'Beh_test2_after_grating.npy',
#     'Beh_train1_after_grating.npy',
#     'LZ13_2024_05_28_1_SVD_dec.npy',
#     'LZ13_2024_05_28_1_neural_data.npy',
#     'LZ13_2024_05_28_trans.npz'],
#    ['Beh_test1_after_grating.npy',
#     'Beh_test2_after_grating.npy',
#     'Beh_train1_after_grating.npy',
#     'LZ13_2024_05_29_1_SVD_dec.npy',
#     'LZ13_2024_05_29_1_neural_data.npy',
#     'LZ13_2024_05_29_trans.npz'],
#    ['Beh_test1_after_grating.npy',
#     'Beh_test2_after_grating.npy',
#     'Beh_train1_after_grating.npy',
#     'LZ16_2024_05_31_2_SVD_dec.npy',
#     'LZ16_2024_05_31_2_neural_data.npy',
#     'LZ16_2024_05_31_trans.npz'],
#    ['Beh_test1_after_grating.npy',
#     'Beh_test2_after_grating.npy',
#     'Beh_train1_after_grating.npy',
#     'LZ16_2024_06_01_1_SVD_dec.npy',
#     'LZ16_2024_06_01_1_neural_data.npy',
#     'LZ16_2024_06_01_trans.npz'],
#    ['Beh_test1_after_grating.npy',
#     'Beh_test2_after_grating.npy',
#     'Beh_train1_after_grating.npy',
#     'TX139_2024_05_31_1_SVD_dec.npy',
#     'TX139_2024_05_31_1_neural_data.npy',
#     'TX139_2024_05_31_trans.npz']]},
#  'naive': {'naive_test1': [['Beh_naive_test1.npy',
#     'Beh_naive_test2.npy',
#     'TX124_2023_12_23_1_SVD_dec.npy',
#     'TX124_2023_12_23_1_neural_data.npy',
#     'TX124_2023_12_23_trans.npz'],
#    ['Beh_naive_test1.npy',
#     'Beh_naive_test2.npy',
#     'TX140_2024_05_31_1_SVD_dec.npy',
#     'TX140_2024_05_31_1_neural_data.npy',
#     'TX140_2024_05_31_trans.npz']]}}

# %%
file_map['supervised']
# Out:
# {'sup_train1_before_learning': [['Beh_sup_train1_before_learning.npy',
#    'TX108_2023_03_13_1_SVD_dec.npy',
#    'TX108_2023_03_13_1_neural_data.npy',
#    'TX108_2023_03_13_trans.npz'],
#   ['Beh_sup_train1_before_learning.npy',
#    'TX109_2023_03_27_1_SVD_dec.npy',
#    'TX109_2023_03_27_1_neural_data.npy',
#    'TX109_2023_03_27_trans.npz'],
#   ['Beh_sup_train1_before_learning.npy',
#    'TX60_2021_04_10_1_SVD_dec.npy',
#    'TX60_2021_04_10_1_neural_data.npy',
#    'TX60_2021_04_10_trans.npz'],
#   ['Beh_sup_train1_before_learning.npy',
#    'VR2_2021_03_20_1_SVD_dec.npy',
#    'VR2_2021_03_20_1_neural_data.npy',
#    'VR2_2021_03_20_trans.npz']],
#  'sup_train1_after_learning': [['Beh_sup_train1_after_learning.npy',
#    'TX108_2023_03_22_1_SVD_dec.npy',
#    'TX108_2023_03_22_1_neural_data.npy',
#    'TX108_2023_03_22_trans.npz'],
#   ['Beh_sup_train1_after_learning.npy',
#    'TX109_2023_04_07_1_SVD_dec.npy',
#    'TX109_2023_04_07_1_neural_data.npy',
#    'TX109_2023_04_07_trans.npz'],
#   ['Beh_sup_train1_after_learning.npy',
#    'TX60_2021_05_04_1_SVD_dec.npy',
#    'TX60_2021_05_04_1_neural_data.npy',
#    'TX60_2021_05_04_trans.npz'],
#   ['Beh_sup_train1_after_learning.npy',
#    'VR2_2021_04_06_1_SVD_dec.npy',
#    'VR2_2021_04_06_1_neural_data.npy',
#    'VR2_2021_04_06_trans.npz']]}

# %%
file_map['unsupervised']
# Out:
# {'unsup_train1_before_learning': [['Beh_unsup_train1_before_learning.npy',
#    'DR10_2022_07_12_1_SVD_dec.npy',
#    'DR10_2022_07_12_1_neural_data.npy',
#    'DR10_2022_07_12_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'DR15_2022_10_09_1_SVD_dec.npy',
#    'DR15_2022_10_09_1_neural_data.npy',
#    'DR15_2022_10_09_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX104_2022_10_12_1_SVD_dec.npy',
#    'TX104_2022_10_12_1_neural_data.npy',
#    'TX104_2022_10_12_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX105_2022_10_08_2_SVD_dec.npy',
#    'TX105_2022_10_08_2_neural_data.npy',
#    'TX105_2022_10_08_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX119_2023_12_14_1_SVD_dec.npy',
#    'TX119_2023_12_14_1_neural_data.npy',
#    'TX119_2023_12_14_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX123_2023_12_21_1_SVD_dec.npy',
#    'TX123_2023_12_21_1_neural_data.npy',
#    'TX123_2023_12_21_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX83_2022_08_17_1_SVD_dec.npy',
#    'TX83_2022_08_17_1_neural_data.npy',
#    'TX83_2022_08_17_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX85_2022_06_14_1_SVD_dec.npy',
#    'TX85_2022_06_14_1_neural_data.npy',
#    'TX85_2022_06_14_trans.npz'],
#   ['Beh_unsup_train1_before_learning.npy',
#    'TX88_2022_06_13_2_SVD_dec.npy',
#    'TX88_2022_06_13_2_neural_data.npy',
#    'TX88_2022_06_13_trans.npz']],
#  'unsup_train1_after_learning': [['Beh_unsup_train1_after_learning.npy',
#    'DR10_2022_07_19_1_SVD_dec.npy',
#    'DR10_2022_07_19_1_neural_data.npy',
#    'DR10_2022_07_19_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'DR15_2022_10_19_1_SVD_dec.npy',
#    'DR15_2022_10_19_1_neural_data.npy',
#    'DR15_2022_10_19_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX104_2022_10_20_1_SVD_dec.npy',
#    'TX104_2022_10_20_1_neural_data.npy',
#    'TX104_2022_10_20_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX105_2022_10_19_2_SVD_dec.npy',
#    'TX105_2022_10_19_2_neural_data.npy',
#    'TX105_2022_10_19_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX119_2023_12_23_1_SVD_dec.npy',
#    'TX119_2023_12_23_1_neural_data.npy',
#    'TX119_2023_12_23_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX123_2024_01_02_1_SVD_dec.npy',
#    'TX123_2024_01_02_1_neural_data.npy',
#    'TX123_2024_01_02_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX83_2022_08_29_1_SVD_dec.npy',
#    'TX83_2022_08_29_1_neural_data.npy',
#    'TX83_2022_08_29_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX85_2022_06_17_1_SVD_dec.npy',
#    'TX85_2022_06_17_1_neural_data.npy',
#    'TX85_2022_06_17_trans.npz'],
#   ['Beh_unsup_train1_after_learning.npy',
#    'TX88_2022_06_17_2_SVD_dec.npy',
#    'TX88_2022_06_17_2_neural_data.npy',
#    'TX88_2022_06_17_trans.npz']]}

# %%
file_map['grating']
# Out:
# {'train1_before_grating': [['Beh_naive_test1.npy',
#    'Beh_naive_test2.npy',
#    'Beh_test1_before_grating.npy',
#    'Beh_test2_before_grating.npy',
#    'Beh_train1_before_grating.npy',
#    'LZ13_2024_05_15_1_SVD_dec.npy',
#    'LZ13_2024_05_15_1_neural_data.npy',
#    'LZ13_2024_05_15_trans.npz'],
#   ['Beh_naive_test1.npy',
#    'Beh_test1_before_grating.npy',
#    'Beh_test2_before_grating.npy',
#    'Beh_train1_before_grating.npy',
#    'LZ13_2024_05_16_2_SVD_dec.npy',
#    'LZ13_2024_05_16_2_neural_data.npy',
#    'LZ13_2024_05_16_trans.npz'],
#   ['Beh_naive_test1.npy',
#    'Beh_naive_test2.npy',
#    'Beh_test1_before_grating.npy',
#    'Beh_test2_before_grating.npy',
#    'Beh_train1_before_grating.npy',
#    'LZ16_2024_05_18_2_SVD_dec.npy',
#    'LZ16_2024_05_18_2_neural_data.npy',
#    'LZ16_2024_05_18_trans.npz'],
#   ['Beh_naive_test1.npy',
#    'Beh_test1_before_grating.npy',
#    'Beh_test2_before_grating.npy',
#    'Beh_train1_before_grating.npy',
#    'LZ16_2024_05_19_1_SVD_dec.npy',
#    'LZ16_2024_05_19_1_neural_data.npy',
#    'LZ16_2024_05_19_trans.npz'],
#   ['Beh_naive_test1.npy',
#    'Beh_naive_test2.npy',
#    'Beh_test1_before_grating.npy',
#    'Beh_test2_before_grating.npy',
#    'Beh_train1_before_grating.npy',
#    'TX139_2024_05_18_1_SVD_dec.npy',
#    'TX139_2024_05_18_1_neural_data.npy',
#    'TX139_2024_05_18_trans.npz']],
#  'train1_after_grating': [['Beh_test1_after_grating.npy',
#    'Beh_test2_after_grating.npy',
#    'Beh_train1_after_grating.npy',
#    'LZ13_2024_05_28_1_SVD_dec.npy',
#    'LZ13_2024_05_28_1_neural_data.npy',
#    'LZ13_2024_05_28_trans.npz'],
#   ['Beh_test1_after_grating.npy',
#    'Beh_test2_after_grating.npy',
#    'Beh_train1_after_grating.npy',
#    'LZ13_2024_05_29_1_SVD_dec.npy',
#    'LZ13_2024_05_29_1_neural_data.npy',
#    'LZ13_2024_05_29_trans.npz'],
#   ['Beh_test1_after_grating.npy',
#    'Beh_test2_after_grating.npy',
#    'Beh_train1_after_grating.npy',
#    'LZ16_2024_05_31_2_SVD_dec.npy',
#    'LZ16_2024_05_31_2_neural_data.npy',
#    'LZ16_2024_05_31_trans.npz'],
#   ['Beh_test1_after_grating.npy',
#    'Beh_test2_after_grating.npy',
#    'Beh_train1_after_grating.npy',
#    'LZ16_2024_06_01_1_SVD_dec.npy',
#    'LZ16_2024_06_01_1_neural_data.npy',
#    'LZ16_2024_06_01_trans.npz'],
#   ['Beh_test1_after_grating.npy',
#    'Beh_test2_after_grating.npy',
#    'Beh_train1_after_grating.npy',
#    'TX139_2024_05_31_1_SVD_dec.npy',
#    'TX139_2024_05_31_1_neural_data.npy',
#    'TX139_2024_05_31_trans.npz']]}

# %%
file_map['naive']
# Out:
# {'naive_test1': [['Beh_naive_test1.npy',
#    'Beh_naive_test2.npy',
#    'TX124_2023_12_23_1_SVD_dec.npy',
#    'TX124_2023_12_23_1_neural_data.npy',
#    'TX124_2023_12_23_trans.npz'],
#   ['Beh_naive_test1.npy',
#    'Beh_naive_test2.npy',
#    'TX140_2024_05_31_1_SVD_dec.npy',
#    'TX140_2024_05_31_1_neural_data.npy',
#    'TX140_2024_05_31_trans.npz']]}

# %%
train1_labels
# Out:
# {'supervised': ('sup_train1_before_learning', 'sup_train1_after_learning'),
#  'unsupervised': ('unsup_train1_before_learning',
#   'unsup_train1_after_learning'),
#  'grating': ('train1_before_grating', 'train1_after_grating'),
#  'naive': ('naive_test1',)}

# %%
import ipywidgets as widgets
from IPython.display import display

def dropdown(options, value, description, onchange = None):
    widget = widgets.Dropdown(
        options=options,
        value=value,
        description=description,
    )
    if onchange is not None:
      widget.observe(onchange, names="value")
    return widget

def dict_array_selector(dict_array):
  keys = list(dict_array.keys())

  def on_key_change(change):
      new_key = change["new"]
      value_dropdown.options = dict_array[new_key]
      if dict_array[new_key]:
          value_dropdown.value = dict_array[new_key][0]

  key_dropdown = dropdown(
      options=keys,
      value=keys[0],
      description="Key:",
      onchange=on_key_change
  )

  value_dropdown = dropdown(
      options=dict_array[keys[0]],
      value=dict_array[keys[0]][0],
      description="Value:"
  )

  return widgets.VBox([key_dropdown, value_dropdown])

def dict_array_selector_values(dict_array_selector):
  return {
      dict_array_selector.children[0].value: dict_array_selector.children[1].value
  }

# %%
sup_train1 = dict_array_selector(file_map['supervised'])

# %%
#@title Join neural and behavior by frame (DuckDB SQL)
import duckdb
import numpy as np
import pandas as pd
from zhong2025.position import align_trailing_behavior_frames

# Load one recording.
choice = dict_array_selector_values(sup_train1)
experiment, selected_files = next(iter(choice.items()))
neural_filename = next(
    name for name in selected_files if name.endswith("_neural_data.npy")
)
recording_id = neural_filename.removesuffix("_neural_data.npy")
recording = data.recording(recording_id)
behavior = recording.load("behavior", experiment=experiment)
svd = recording.load("reduced_neural")

U = np.asarray(svd["U"])
V = np.asarray(svd["V"])
moving = (
    np.asarray(behavior["ft_isMoving"])
    if "ft_isMoving" in behavior
    else np.asarray(behavior["ft_move"]) > 0
)

# Synchronize the two time series before doing relational joins.
V_by_frame, aligned, report = align_trailing_behavior_frames(
    V.T,
    {
        "trial_id": behavior["ft_trInd"],
        "position_dm": behavior["ft_Pos"],
        "is_moving": moving,
        "run_speed": behavior["ft_RunSpeed"],
    },
    max_trailing_behavior_frames=3,
)

# Three small tables, joined through explicit keys:
# frame -> trial_id -> wall_name -> stim_id
trial_raw = np.asarray(aligned["trial_id"], dtype=float)
integer_trial = np.isfinite(trial_raw) & np.isclose(trial_raw, np.rint(trial_raw))
trial_id = pd.Series(trial_raw).where(integer_trial).round().astype("Int64")

neural_frames = pd.DataFrame(
    V_by_frame[:, :8],
    columns=[f"PC{i + 1}" for i in range(8)],
)
neural_frames.insert(0, "frame", np.arange(len(V_by_frame)))

behavior_frames = pd.DataFrame({
    "frame": np.arange(len(V_by_frame)),
    "trial_id": trial_id,
    "position_dm": np.asarray(aligned["position_dm"], dtype=float),
    "is_moving": np.asarray(aligned["is_moving"], dtype=bool),
    "run_speed": np.asarray(aligned["run_speed"], dtype=float),
})

trial_lookup = pd.DataFrame({
    "trial_id": np.arange(len(behavior["WallName"])),
    "wall_name": np.asarray(behavior["WallName"]),
})

stimulus_lookup = pd.DataFrame({
    "wall_name": np.asarray(behavior["UniqWalls"]),
    "stim_id": pd.to_numeric(
        pd.Series(np.asarray(behavior["stim_id"])),
        errors="coerce",
    ).astype("Int64"),
})

joined = duckdb.sql("""
    SELECT
        n.frame,
        t.trial_id IS NOT NULL AS valid_trial,
        COALESCE(t.trial_id, -1)::BIGINT AS trial_id,
        b.position_dm,
        b.position_dm / 10.0 AS position_m,
        b.is_moving,
        b.run_speed,
        t.wall_name,
        COALESCE(s.stim_id, -1)::INTEGER AS stim_id,
        n.* EXCLUDE (frame)
    FROM neural_frames AS n
    JOIN behavior_frames AS b USING (frame)
    LEFT JOIN trial_lookup AS t ON b.trial_id = t.trial_id
    LEFT JOIN stimulus_lookup AS s ON t.wall_name = s.wall_name
    ORDER BY n.frame
""").df()

assert len(joined) == report.neural_frames
assert joined["frame"].is_unique

print("Experiment:", experiment)
print("Recording:", recording_id)
print(report)
print("Joined:", joined.shape)
print("Frames without a valid trial:", int((~joined["valid_trial"]).sum()))
joined.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator TruncatedSVD from version 1.6.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Experiment: sup_train1_before_learning
# Recording: TX108_2023_03_13_1
# AlignmentReport({'neural_frames': 22992,
#  'behavior_frames': 22994,
#  'dropped_trailing_behavior_frames': 2})
# Joined: (22992, 17)
# Frames without a valid trial: 451
#    frame  valid_trial  trial_id  position_dm  position_m  is_moving  \
# 0      0        False        -1          0.0         0.0      False
# 1      1        False        -1          0.0         0.0      False
# 2      2        False        -1          0.0         0.0      False
# 3      3        False        -1          0.0         0.0      False
# 4      4        False        -1          0.0         0.0      False
#
#    run_speed wall_name  stim_id        PC1        PC2        PC3        PC4  \
# 0        0.0      None       -1 -96.896416 -19.745535  19.372732   4.303491
# 1        0.0      None       -1 -30.980862  10.208312 -33.698513 -12.935389
# 2        0.0      None       -1 -46.988190   5.797575 -27.264818 -13.179980
# 3        0.0      None       -1 -55.755981   1.658184 -23.207844 -11.569946
# 4        0.0      None       -1 -59.708641   0.671134 -23.358791  -9.317326
#
#          PC5        PC6        PC7       PC8
# 0   1.601870  -5.782473   2.628757 -0.374347
# 1 -10.487078 -10.448918 -12.770697  1.232575
# 2 -11.395247 -13.648425 -16.121849  4.097371
# 3 -12.434927 -13.354087 -16.513439  4.912840
# 4 -10.450589 -12.567168 -15.484608  4.695628

# %%
#@title Count moving texture frames with SQL
stimulus_counts = duckdb.sql("""
    SELECT
        COUNT(*) FILTER (WHERE stim_id = 2) AS leaf_frames,
        COUNT(*) FILTER (WHERE stim_id = 0) AS circle_frames
    FROM joined
    WHERE valid_trial
      AND is_moving
      AND position_m >= 0
      AND position_m < 4
""").df().iloc[0]

leaf_frame_count = int(stimulus_counts["leaf_frames"])
circle_frame_count = int(stimulus_counts["circle_frames"])

print("Leaf frames:", leaf_frame_count)
print("Circle frames:", circle_frame_count)
assert leaf_frame_count == 3152
assert circle_frame_count == 2712
# Out:
# Leaf frames: 3152
# Circle frames: 2712

# %%
from zhong2025.learning import prepare_session_trials

retinotopy = recording.load("retinotopy")

trial_data = prepare_session_trials(
    behavior,
    svd,
    retinotopy,
    area="V1",
    n_features=12,
    n_position_bins=18,
    movement_rule="moving_only",
    mouse_id=recording.mouse,
    recording_id=recording.recording_id,
)

print("trial_features:", trial_data["trial_features"].shape)
print("run_speed:", trial_data["run_speed"].shape)
print("labels:", trial_data["labels"].shape)
print("alignment:", trial_data["alignment"])
# Out:
# trial_features: (210, 18, 12)
# run_speed: (210, 18)
# labels: (210,)
# alignment: AlignmentReport({'neural_frames': 22992,
#  'behavior_frames': 22994,
#  'dropped_trailing_behavior_frames': 2})

# %%
#@title Verify the neural-behavior join end to end
import numpy as np
from pprint import pprint

from zhong2025.position import (
    align_trailing_behavior_frames,
    bin_trial_features,
    decimeters_to_meters,
)
from zhong2025.learning import area_transform

U_check = np.asarray(svd["U"])
V_check = np.asarray(svd["V"])
moving_check = (
    np.asarray(behavior["ft_isMoving"])
    if "ft_isMoving" in behavior
    else np.asarray(behavior["ft_move"]) > 0
)

V_frames_check, behavior_check, alignment_check = align_trailing_behavior_frames(
    V_check.T,
    {
        "position_dm": behavior["ft_Pos"],
        "trial_id": behavior["ft_trInd"],
        "is_moving": moving_check,
        "run_speed": behavior["ft_RunSpeed"],
    },
    max_trailing_behavior_frames=3,
)

position_m_check = decimeters_to_meters(behavior_check["position_dm"])
trial_raw_check = np.asarray(behavior_check["trial_id"], dtype=float)
valid_join_frames = (
    np.asarray(behavior_check["is_moving"], dtype=bool)
    & np.isfinite(position_m_check)
    & np.isfinite(trial_raw_check)
    & (position_m_check >= 0.0)
    & (position_m_check <= 6.0)
)

# Independently reconstruct the trial x position binning.
edges_check = np.linspace(0.0, 6.0, 19)
trial_ids_check, binned_v_check, counts_check = bin_trial_features(
    V_frames_check,
    position_m_check,
    trial_raw_check,
    edges_check,
    valid_mask=valid_join_frames,
)
speed_ids_check, speed_check, speed_counts_check = bin_trial_features(
    behavior_check["run_speed"],
    position_m_check,
    trial_raw_check,
    edges_check,
    valid_mask=valid_join_frames,
)

# Independently reconstruct the V1 feature projection.
transform_check = area_transform(
    U_check,
    retinotopy["iarea"],
    "V1",
    n_features=12,
)
features_check = np.einsum(
    "tbp,pk->tbk",
    binned_v_check,
    transform_check,
    optimize=True,
).astype(np.float32)

# Independently reconstruct trial labels.
wall_names_check = np.asarray(behavior["WallName"])
wall_by_trial_check = wall_names_check[trial_ids_check]
wall_to_role_check = {}
for wall, role in zip(
    np.asarray(behavior["UniqWalls"]),
    np.asarray(behavior["stim_id"]),
):
    try:
        if np.isfinite(role):
            wall_to_role_check[str(wall)] = int(role)
    except TypeError:
        pass

labels_check = np.asarray(
    [wall_to_role_check.get(str(wall), -1) for wall in wall_by_trial_check],
    dtype=np.int16,
)

# Frame-level label support, safely excluding NaN/out-of-range ft_trInd.
integer_trial_frames = np.isfinite(trial_raw_check) & np.isclose(
    trial_raw_check,
    np.rint(trial_raw_check),
)
frame_trial_ids_check = np.full(len(trial_raw_check), -1, dtype=np.int64)
frame_trial_ids_check[integer_trial_frames] = np.rint(
    trial_raw_check[integer_trial_frames]
).astype(np.int64)
in_range_trial_frames = (
    integer_trial_frames
    & (frame_trial_ids_check >= 0)
    & (frame_trial_ids_check < len(wall_names_check))
)
frame_roles_check = np.full(len(trial_raw_check), -1, dtype=np.int16)
frame_walls_check = np.full(len(trial_raw_check), None, dtype=object)
frame_walls_check[in_range_trial_frames] = wall_names_check[
    frame_trial_ids_check[in_range_trial_frames]
]
frame_roles_check[in_range_trial_frames] = [
    wall_to_role_check.get(str(wall), -1)
    for wall in frame_walls_check[in_range_trial_frames]
]
texture_moving_check = (
    valid_join_frames
    & (position_m_check < 4.0)
    & in_range_trial_frames
)
leaf_frame_count = int(np.count_nonzero(
    texture_moving_check & (frame_roles_check == 2)
))
circle_frame_count = int(np.count_nonzero(
    texture_moving_check & (frame_roles_check == 0)
))

# Hard assertions: any failure stops here with a precise traceback.
assert recording.recording_id == "TX108_2023_03_13_1"
assert experiment == "sup_train1_before_learning"
assert U_check.ndim == 2 and V_check.ndim == 2
assert U_check.shape[0] == V_check.shape[0]
assert U_check.shape[1] == len(np.asarray(retinotopy["iarea"]))
assert V_check.shape[1] == alignment_check.neural_frames
assert alignment_check.behavior_frames - alignment_check.neural_frames == alignment_check.dropped_trailing_behavior_frames
assert alignment_check.dropped_trailing_behavior_frames <= 3
assert all(len(values) == alignment_check.neural_frames for values in behavior_check.values())
assert np.array_equal(trial_ids_check, speed_ids_check)
assert np.array_equal(counts_check, speed_counts_check)
assert np.array_equal(trial_ids_check, trial_data["trial_id"])
assert np.array_equal(counts_check, trial_data["frame_counts"])
assert np.allclose(speed_check[:, :, 0], trial_data["run_speed"], equal_nan=True)
assert np.allclose(features_check, trial_data["trial_features"], equal_nan=True, rtol=1e-5, atol=1e-5)
assert np.array_equal(wall_by_trial_check, trial_data["wall_name"])
assert np.array_equal(labels_check, trial_data["labels"])
assert trial_data["trial_features"].shape == (210, 18, 12)
assert trial_data["run_speed"].shape == (210, 18)
assert trial_data["labels"].shape == (210,)
assert trial_data["frame_counts"].shape == (210, 18)
assert len(trial_data["position_centers_m"]) == 18
assert np.all(trial_data["frame_counts"] >= 0)
assert leaf_frame_count > 0 and circle_frame_count > 0
assert 0 in set(trial_data["labels"]) and 2 in set(trial_data["labels"])

label_values, label_counts = np.unique(
    trial_data["labels"],
    return_counts=True,
)
verification_summary = {
    "status": "ALL CHECKS PASSED",
    "recording_id": recording.recording_id,
    "experiment": experiment,
    "U_components_x_neurons": U_check.shape,
    "V_components_x_frames": V_check.shape,
    "alignment": alignment_check.to_dict(),
    "trial_features": trial_data["trial_features"].shape,
    "run_speed": trial_data["run_speed"].shape,
    "frame_counts": trial_data["frame_counts"].shape,
    "label_counts": dict(zip(label_values.tolist(), label_counts.tolist())),
    "moving_texture_leaf_frames": leaf_frame_count,
    "moving_texture_circle_frames": circle_frame_count,
    "unassigned_frame_count": int(np.count_nonzero(~in_range_trial_frames)),
    "empty_trial_position_bins": int(np.count_nonzero(trial_data["frame_counts"] == 0)),
    "finite_neural_fraction": float(np.mean(np.isfinite(trial_data["trial_features"]))),
    "finite_speed_fraction": float(np.mean(np.isfinite(trial_data["run_speed"]))),
}
pprint(verification_summary)
# Out:
# {'U_components_x_neurons': (400, 85481),
#  'V_components_x_frames': (400, 22992),
#  'alignment': {'behavior_frames': 22994,
#                'dropped_trailing_behavior_frames': 2,
#                'neural_frames': 22992},
#  'empty_trial_position_bins': 0,
#  'experiment': 'sup_train1_before_learning',
#  'finite_neural_fraction': 1.0,
#  'finite_speed_fraction': 1.0,
#  'frame_counts': (210, 18),
#  'label_counts': {0: 98, 2: 112},
#  'moving_texture_circle_frames': 2712,
#  'moving_texture_leaf_frames': 3152,
#  'recording_id': 'TX108_2023_03_13_1',
#  'run_speed': (210, 18),
#  'status': 'ALL CHECKS PASSED',
#  'trial_features': (210, 18, 12),
#  'unassigned_frame_count': 451}
